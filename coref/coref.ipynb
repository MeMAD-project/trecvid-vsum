# %%
! pip -q install neuralcoref

# %%
import spacy
import pickle
from collections import Counter

# %%
import neuralcoref

# %%
! python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: en_core_web_lg==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.1.0/en_core_web_lg-2.1.0.tar.gz#egg=en_core_web_lg==2.1.0 in /home/ismail/anaconda3/lib/python3.7/site-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
neuralcoref.add_to_pipe(nlp)

# %%
! ls
# Out:
# coref.ipynb	      episodes_data.pickle		summaries.txt
# coref_results.pickle  query_character_summaries.pickle	Summary.ipynb

# %%
import pickle

# %%
d = pickle.load(open('episodes_data.pickle', 'rb'))

# %%
full_text = {}
for ep in d:
    full_text[ep] = [s[1].replace('\n', ' ').replace('Billie', 'Billy') for s in d[ep]['summaries']]

# %%
full_text['5531550228324592939.mp4']
# Out:
# ['Kat persuades Stacey and Jean to come to R&R with her and Kim, leaving Charlie and Alfie to look after Lily. Alfie quickly escapes to the barrel store. There, Alfie fixes the new television to the wall, it falls off and smashes. Alfie joins the girls in R&R. Charlie has to pick up Mo and leaves Lily with Pat. Lily won’t settle so Pat takes her for a walk. Janine accuses Ryan of wanting to go to R&R because he knew Stacey would be there. Ryan denies it and leaves, Janine stays in the club. Julie explains that she was moved to another home when pregnant, their baby was taken away a week after she gave birth. Billy’s angry, first saying the baby should have stayed with them, then insisting Julie shouldn’t have told him about their son at all. Julie leaves, telling Billy he hasn’t changed. Carol ends up in R&R, Billy joins her. The pair get drunk together. Carol cries, Billy tries to kiss her. When Carol rejects his advances, Billy insults her. Billy then unsuccessfully propositions Jean. Stacey realises Billy’s upset her mum, Janine and Kat get drawn into their argument before Alfie steps in. Ricky takes Carol home, Bianca storms to R&R to confront Billy. Giving Lily to Ryan, Pat follows Bianca into the club, worried. Bianca shouts at Billy. When Bianca backs off, Billy says she’s just like all the other ‘scrubbers’ there. Billy then turns on Stacey, who hits him. Janine pulls out a chunk of Stacey’s hair. Kat and Janine hit each other. Billy staggers away from the fight. Someone puts their hand on Billy’s shoulder, he instinctively turns round and hits them - unfortunately it’s a policeman. Roxy’s jealous when Christian brings Syed to R&R. Christian’s furious when Roxy deliberately spikes Syed’s drink. ',
#  'Kim, Kat, Stacey, Pat and Janine are shut in a cell together. Stacey’s worried about Lily, and Pat admits she’s with Ryan, not Charlie. Stacey asks the police officer to phone Ryan. The girls play a game,\xa0each saying something they’ve never done, to discover who else has done it. When Janine taunts Stacey, Stacey blurts out ‘I’ve never been engaged to a dirty old rapist’. Janine doesn’t believe it. Stacey quickly backtracks, then becomes distressed and when Pat gently asks if Archie raped her, she nods. Pat and Kat think this explains why Bradley killed Archie. Pat and Janine discuss Ryan, Stacey’s lies awake, listening. The next morning, the police let the women go with a caution. Billy and Alfie are locked in another cell. Billy talks about the horrors he experienced in care. An officer tells Billy they’re not going to press charges. Alfie’s frustrated when this doesn’t cheer Billy up. Billy has a panic attack and Alfie calmly talks him through it. Billy thanks Alfie and remembers Julie used to calm him down like that.
all_chars = []
for ep in d:
    all_chars.extend(d[ep]['characters'])
len(set(all_chars))
# Out:
# 87

# %%
ep_characters = {}
for ep in d:
    ep_characters[ep] = [c.split(' ')[0] for c in d[ep]['characters']]

# %%
ep_characters
# Out:
# {'5531550228324592939.mp4': ['Carol',
#   'Bianca',
#   'Liam',
#   'Ricky',
#   'Whitney',
#   'Max',
#   'Jack',
#   'Dot',
#   'Lauren',
#   'Pat',
#   'Ryan',
#   'Janine',
#   'Stacey',
#   'Kat',
#   'Alfie',
#   'Roxy',
#   'Phil',
#   'Billy',
#   'Julie',
#   'Jay',
#   'Christian',
#   'Syed',
#   'Kim',
#   'Jean',
#   'Jim',
#   'Charlie',
#   'Patrick',
#   'Morgan',
#   'Sgt'],
#  '5534228999422914578.mp4': ['Janine',
#   'Ryan',
#   'Stacey',
#   'Kat',
#   'Alfie',
#   'Carol',
#   'Glenda',
#   'Pat',
#   'Bianca',
#   'Ricky',
#   'Max',
#   'Lauren',
#   'Jack',
#   'Vanessa',
#   'Darren',
#   'Jodie',
#   'Jay',
#   'Billy',
#   'Julie',
#   'Charlie',
#   'Jean',
#   'Masood',
#   'Arthur',
#   'Mercy',
#   'Tanya',
#   'Greg',
#   'Dot',
#   'Jim',
#   'Alan',
#   'Blossom',
#   'Harry',
#   'Abi',
#   'Liam',
#   'Morgan',
#   'Whitney',
#   'Peter',
#   'Tracey',
#   'Connor',
#   'Mitch',
#   'Mr',
#   'Vicky'],
#  '5539381671692122744.mp4': ['Vanessa',
#   'Jodie',
#   'Harry',
#   'Max',
#   'Darren',
#   'Kat',
#   'Alfie',
#   'Roxy',
#   'Ronnie',
#   'Jack',
#   'Ian',
#   'Jane',
#   'Connor',
#   'Sal',
#   'Bianca',
#   'Stacey',
#   'Mo',
#   'Charlie',
#   'Jean',
#   'Glenda',
#   'Carol',
#   'Billy',
#   'Jay',
#   'Kim',
#   'Heather',
#   'Phil',
#   'Shirley',
#   'Masood',
#   'Tamwar',
#   'Julie',
#   'Dot',
#   'Lauren',
#   'Jim',
#   'Hotel',
#   'Superintendent',
#   'Stripper'],
#  '5542003749222140011.mp4': ['Max',
#   'Jean',
#   'Ryan',
#   'Stacey',
#   'Lauren',
#   'Vanessa',
#   'Shirley',
#   'Phil',
#   'Billy',
#   'Julie',
#   'Roxy',
#   'Tamwar',
#   'Afia',
#   'Zainab',
#   'Masood',
#   'Jodie',
#   'Darren',
#   'Bianca',
#   'Carol',
#   'Connor',
#   'Connor',
#   'Janine',
#   'Heather',
#   'Whitney',
#   'Peter',
#   'Tiffany',
#   'Abi'],
#  '5544574287152993687.mp4': ['Masood',
#   'Jane',
#   'Ian',
#   'Zainab',
#   'Janine',
#   'Ryan',
#   'Pat',
#   'Phil',
#   'Glenda',
#   'Shirley',
#   'Alfie',
#   'Kat',
#   'Bianca',
#   'Carol',
#   'Connor',
#   'Patrick',
#   'Billy',
#   'Christian',
#   'Peter',
#   'Tamwar',
#   'Afia',
#   'Yusef',
#   'Ricky',
#   'Denise',
#   'Mo',
#   'Whitney',
#   'Jay',
#   'Vanessa',
#   'Lauren',
#   'Max',
#   'Roxy',
#   'Heather',
#   'Mr',
#   'Bushra',
#   'Maria',
#   'Lad'],
#  '5544620672795594434.mp4': ['Masood',
#   'Jane',
#   'Ian',
#   'Zainab',
#   'Janine',
#   'Ryan',
#   'Pat',
#   'Phil',
#   'Glenda',
#   'Shirley',
#   'Alfie',
#   'Kat',
#   'Bianca',
#   'Carol',
#   'Connor',
#   'Patrick',
#   'Billy',
#   'Christian',
#   'Peter',
#   'Tamwar',
#   'Afia',
#   'Yusef',
#   'Ricky',
#   'Denise',
#   'Mo',
#   'Whitney',
#   'Jay',
#   'Vanessa',
#   'Lauren',
#   'Max',
#   'Roxy',
#   'Heather',
#   'Mr',
#   'Bushra',
#   'Maria',
#   'Lad'],
#  '5547193787702629969.mp4': ['Billy',
#   'Julie',
#   'Ryan',
#   'Stacey',
#   'Masood',
#   'Zainab',
#   'Jane',
#   'Ian',
#   'Glenda',
#   'Kat',
#   'Janine',
#   'Syed',
#   'Christian',
#   'Tamwar',
#   'Afia',
#   'Dot',
#   'Heather',
#   'Arthur',
#   'Phil',
#   'Carol',
#   'Charlie',
#   'Jean',
#   'Mo',
#   'Patrick',
#   'Jim',
#   'Peter',
#   'Lauren',
#   'Grace',
#   'Mercy',
#   'Edward',
#   'Cab'],
#  '5549784941472309008.mp4': ['Janine',
#   'Ryan',
#   'Stacey',
#   'Kat',
#   'Jean',
#   'Pat',
#   'Glenda',
#   'Phil',
#   'Billy',
#   'Julie',
#   'Ian',
#   'Jane',
#   'Peter',
#   'Whitney',
#   'Christian',
#   'Syed',
#   'Lauren',
#   'Arthur',
#   'Dot',
#   'Alfie',
#   'Shirley',
#   'Jay',
#   'Mo',
#   'Bobby',
#   'Connor',
#   'Maria',
#   'Roger',
#   'Policeman'],
#  '5552368364300855101.mp4': ['Janine',
#   'Ryan',
#   'Stacey',
#   'Ronnie',
#   'Jack',
#   'Max',
#   'Glenda',
#   'Ian',
#   'Jane',
#   'Peter',
#   'Phil',
#   'Shirley',
#   'Ben',
#   'Jay',
#   'Whitney',
#   'Carol',
#   'Bianca',
#   'Ricky',
#   'Kat',
#   'Jean',
#   'Denise',
#   'Kim',
#   'Dot',
#   'Arthur',
#   'Billy',
#   'Julie',
#   'Roxy',
#   'Lauren',
#   'Abi',
#   'Heather',
#   'Alfie',
#   'Pat',
#   'Connor',
#   'Morgan'],
#  '5555325449284154780.mp4': ['Ryan',
#   'Janine',
#   'Stacey',
#   'Max',
#   'Jean',
#   'Ronnie',
#   'Roxy',
#   'Kat',
#   'Alfie',
#   'Lauren',
#   'Tanya',
#   'Abi',
#   'Greg',
#   'Vanessa',
#   'Dot',
#   'Pat',
#   'Bianca',
#   'Ricky',
#   'Charlie',
#   'Mo',
#   'Phil',
#   'Shirley',
#   'Heather',
#   'Billy',
#   'Julie',
#   'Jay',
#   'Ben',
#   'Kim',
#   'Denise',
#   'Jordan',
#   'Gloria',
#   'Arthur',
#   'Darren',
#   'Jodie',
#   'Mercy',
#   'Patrick',
#   'Ian',
#   'Jane',
#   'Peter',
#   'Glenda',
#   'Carol',
#   'Whitney',
#   'Connor',
#   'Zainab',
#   'Edward',
#   'Liam',
#   'Tiffany',
#   'Morgan',
#   'Bobby',
#   'PC',
#   'PC',
#   'Stallholder',
#   'Doctor',
#   'Nurse'],
#  '5555360238519252381.mp4': ['Ryan',
#   'Janine',
#   'Stacey',
#   'Max',
#   'Jean',
#   'Ronnie',
#   'Roxy',
#   'Kat',
#   'Alfie',
#   'Lauren',
#   'Tanya',
#   'Abi',
#   'Greg',
#   'Vanessa',
#   'Dot',
#   'Pat',
#   'Bianca',
#   'Ricky',
#   'Charlie',
#   'Mo',
#   'Phil',
#   'Shirley',
#   'Heather',
#   'Billy',
#   'Julie',
#   'Jay',
#   'Ben',
#   'Kim',
#   'Denise',
#   'Jordan',
#   'Gloria',
#   'Arthur',
#   'Darren',
#   'Jodie',
#   'Mercy',
#   'Patrick',
#   'Ian',
#   'Jane',
#   'Peter',
#   'Glenda',
#   'Carol',
#   'Whitney',
#   'Connor',
#   'Zainab',
#   'Edward',
#   'Liam',
#   'Tiffany',
#   'Morgan',
#   'Bobby',
#   'PC',
#   'PC',
#   'Stallholder',
#   'Doctor',
#   'Nurse']}

# %%
query_characters = ['Janine', 'Ryan', 'Stacey']

# %%
l = doc._.coref_clusters

# %%
[l.text for l in doc]
# Out:
# ['Janine',
#  'recovers',
#  'from',
#  'the',
#  'dramatic',
#  'events',
#  'of',
#  'Christmas',
#  'Day',
#  'while',
#  'the',
#  'Square',
#  'deals',
#  'with',
#  'the',
#  'fallout',
#  'from',
#  'Stacey',
#  "'s",
#  'departure',
#  '.',
#  'Pat',
#  'struggles',
#  'to',
#  'come',
#  'to',
#  'terms',
#  'with',
#  'an',
#  'awful',
#  'truth',
#  ',',
#  'and',
#  'has',
#  'Kat',
#  "'s",
#  'Christmas',
#  'wish',
#  'finally',
#  'come',
#  'true',
#  '?',
#  'Bianca',
#  'and',
#  'Phil',
#  'form',
#  'an',
#  'uneasy',
#  'alliance',
#  'in',
#  'order',
#  'to',
#  'trap',
#  'Connor',
#  ',',
#  'and',
#  'Dot',
#  'hosts',
#  'a',
#  'Boxing',
#  'Day',
#  'party',
#  '.']

# %%
marked = {}
for ep in d:
    marked[ep] = []
    for i, episode_summary in enumerate(full_text[ep]):
        episode_characters = all_characters[ep]
        doc = nlp(episode_summary)
        
        marks = []
        
        for c in doc._.coref_clusters:
            for m in c.mentions:
                if c.main.text in query_characters:
                    marks.append(('@', m.start, c.main.text,  m.text))
                elif c.main.text in episode_characters:
                    marks.append(('#', m.start, c.main.text,  m.text))
                elif len(c.main.text.split(' ')) == 1 :
                    marks.append(('~', m.start, c.main.text,  m.text))
        
        summary_chars = [l.text for l in doc]
        marks = sorted(marks, key=lambda x: x[1])
        
        # print(marks)
        
        for i, (m, ix, text, original) in enumerate(marks):
            at = ix
            try:
                summary_chars.pop(at)
                summary_chars.insert(at, m + text)
            except:
                print(i + ix)
        
        # print(' '.join(summary_chars))
        marked[ep].append(summary_chars)

# %%
marked['5531550228324592939.mp4']
# Out:
# [['#Kat',
#   'persuades',
#   '@Stacey',
#   'and',
#   'Jean',
#   'to',
#   'come',
#   'to',
#   '~R&R',
#   'with',
#   '#Kat',
#   'and',
#   'Kim',
#   ',',
#   'leaving',
#   '#Charlie',
#   'and',
#   '#Alfie',
#   'to',
#   'look',
#   'after',
#   '~Lily',
#   '.',
#   '#Alfie',
#   'quickly',
#   'escapes',
#   'to',
#   'the',
#   'barrel',
#   'store',
#   '.',
#   'There',
#   ',',
#   '#Alfie',
#   'fixes',
#   'the',
#   'new',
#   'television',
#   'to',
#   'the',
#   'wall',
#   ',',
#   'it',
#   'falls',
#   'off',
#   'and',
#   'smashes',
#   '.',
#   '#Alfie',
#   'joins',
#   'the',
#   'girls',
#   'in',
#   'R&R.',
#   '#Charlie',
#   'has',
#   'to',
#   'pick',
#   'up',
#   'Mo',
#   'and',
#   'leaves',
#   '~Lily',
#   'with',
#   '#Pat',
#   '.',
#   '~Lily',
#   'wo',
#   'n’t',
#   'settle',
#   'so',
#   '#Pat',
#   'takes',
#   '~Lily',
#   'for',
#   'a',
#   'walk',
#   '.',
#   '@Janine',
#   'accuses',
#   '@Ryan',
#   'of',
#   'wanting',
#   'to',
#   'go',
#   'to',
#   '~R&R',
#   'because',
#   '~R&R',
#   'knew',
#   '@Stacey',
#   'would',
#   'be',
#   'there',
#   '.',
#   '@Ryan',
#   'denies',
#   'it',
#   'and',
#   'leaves',
#   ',',
#   '@Janine',
#   'stays',
#   'in',
#   'the',
#   'club',
#   '.',
#   '#Julie',
#   'explains',
#   'that',
#   '@Janine',
#   'was',
#   'moved',
#   'to',
#   'another',
#   'home',
#   'when',
#   'pregnant',
#   ',',
#   '~their',
#   'baby',
#   'was',
#   'taken',
#   'away',
#   'a',
#   'week',
#   'after',
#   '@Janine',
#   'gave',
#   'birth',
#   '.',
#   '#Billy',
#   '’s',
#   'angry',
#   ',',
#   'first',
#   'saying',
#   'the',
#   'baby',
#   'should',
#   'have',
#   'stayed',
#   'with',
#   '~their',
#   ',',
#   'then',
#   'insisting',
#   '#Julie',
#   'should',
#   'n’t',
#   'have',
#   'told',
#   'him',
#   'about',
#   '~their',
#   'son',
#   'at',
#   'all',
#   '.',
#   '#Julie',
#   'leaves',
#   ',',
#   'telling',
#   '#Billy',
#   '#Billy',
#   'has',
#   'n’t',
#   'changed',
#   '.',
#   '#Carol',
#   'ends',
#   'up',
#   'in',
#   '~R&R',
#   ',',
#   '#Billy',
#   'joins',
#   '#Carol',
#   '.',
#   'The',
#   'pair',
#   'get',
#   'drunk',
#   'together',
#   '.',
#   '#Carol',
#   'cries',
#   ',',
#   '#Billy',
#   'tries',
#   'to',
#   'kiss',
#   '#Carol',
#   '.',
#   'When',
#   '#Carol',
#   'rejects',
#   '#Billy',
#   'advances',
#   ',',
#   '#Billy',
#   'insults',
#   '#Carol',
#   '.',
#   '#Billy',
#   'then',
#   'unsuccessfully',
#   'propositions',
#   'Jean',
#   '.',
#   '@Stacey',
#   'realises',
#   '#Billy',
#   '’s',
#   'upset',
#   '@Stacey',
#   'mum',
#   ',',
#   '@Janine',
#   'and',
#   '#Kat',
#   'get',
#   'drawn',
#   'into',
#   'their',
#   'argument',
#   'before',
#   'Alfie',
#   'steps',
#   'in',
#   '.',
#   'Ricky',
#   'takes',
#   '#Carol',
#   'home',
#   ',',
#   '#Bianca',
#   'storms',
#   'to',
#   '~R&R',
#   'to',
#   'confront',
#   '#Billy',
#   '.',
#   'Giving',
#   'Lily',
#   'to',
#   'Ryan',
#   ',',
#   'Pat',
#   'follows',
#   '#Bianca',
#   'into',
#   'the',
#   'club',
#   ',',
#   'worried',
#   '.',
#   '#Bianca',
#   'shouts',
#   'at',
#   '#Billy',
#   '.',
#   'When',
#   '#Bianca',
#   'backs',
#   'off',
#   ',',
#   '#Billy',
#   'says',
#   '#Bianca',
#   '’s',
#   'just',
#   'like',
#   'all',
#   'the',
#   'other',
#   '‘',
#   'scrubbers',
#   '’',
#   'there',
#   '.',
#   '#Billy',
#   'then',
#   'turns',
#   'on',
#   'Stacey',
#   ',',
#   'who',
#   'hits',
#   '#Billy',
#   '.',
#   '@Janine',
#   'pulls',
#   'out',
#   'a',
#   'chunk',
#   'of',
#   '@Stacey',
#   '’s',
#   'hair',
#   '.',
#   '#Kat',
#   'and',
#   '@Janine',
#   'hit',
#   'each',
#   'other',
#   '.',
#   '#Billy',
#   'staggers',
#   'away',
#   'from',
#   'the',
#   'fight',
#   '.',
#   'Someone',
#   'puts',
#   'their',
#   'hand',
#   'on',
#   '#Billy',
#   '’s',
#   'shoulder',
#   ',',
#   '#Billy',
#   'instinctively',
#   'turns',
#   'round',
#   'and',
#   'hits',
#   'them',
#   '-',
#   'unfortunately',
#   'it',
#   '’s',
#   'a',
#   'policeman',
#   '.',
#   '#Roxy',
#   '’s',
#   'jealous',
#   'when',
#   'Christian',
#   'brings',
#   '#Syed',
#   'to',
#   'R&R.',
#   'Christian',
#   '’s',
#   'furious',
#   'when',
#   '#Roxy',
#   'deliberately',
#   'spikes',
#   '#Syed',
#   '’s',
#   'drink',
#   '.'],
#  ['Kim',
#   ',',
#   'Kat',
#   ',',
#   'Stacey',
#   ',',
#   '#Pat',
#   'and',
#   '@Janine',
#   'are',
#   'shut',
#   'in',
#   'a',
#   'cell',
#   'together',
#   '.',
#   '~Stacey’s',
#   '’s',
#   'worried',
#   'about',
#   'Lily',
#   ',',
#   'and',
#   '#Pat',
#   'admits',
#   '@Stacey',
#   '’s',
#   'with',
#   '@Ryan',
#   ',',
#   'not',
#   'Charlie',
#   '.',
#   '@Stacey',
#   'asks',
#   'the',
#   'police',
#   'officer',
#   'to',
#   'phone',
#   '@Ryan',
#   '.',
#   'The',
#   'girls',
#   'play',
#   'a',
#   'game',
#   ',',
#   '\xa0',
#   'each',
#   'saying',
#   'something',
#   'they',
#   '’ve',
#   'never',
#   'done',
#   ',',
#   'to',
#   'discover',
#   'who',
#   'else',
#   'has',
#   'done',
#   '~it',
#   '.',
#   'When',
#   '@Janine',
#   'taunts',
#   '@Stacey',
#   ',',
#   '@Stacey',
#   'blurts',
#   'out',
#   '‘',
#   'I',
#   '’ve',
#   'never',
#   'been',
#   'engaged',
#   'to',
#   'a',
#   'dirty',
#   'old',
#   'rapist',
#   '’',
#   '.',
#   '@Janine',
#   'does',
#   'n’t',
#   'believe',
#   '~it',
#   '.',
#   '@Stacey',
#   'quickly',
#   'backtracks',
#   ',',
#   'then',
#   'becomes',
#   'distressed',
#   'and',
#   'when',
#   '#Pat',
#   'gently',
#   'asks',
#   'if',
#   '~Archie',
#   'raped',
#   '@Stacey',
#   ',',
#   '@Stacey',
#   'nods',
#   '.',
#   '#Pat',
#   'and',
#   '#Kat',
#   'think',
#   'this',
#   'explains',
#   'why',
#   'Bradley',
#   'killed',
#   '~Archie',
#   '.',
#   '#Pat',
#   'and',
#   '@Janine',
#   'discuss',
#   '@Ryan',
#   ',',
#   '~Stacey’s',
#   '’s',
#   'lies',
#   'awake',
#   ',',
#   'listening',
#   '.',
#   'The',
#   'next',
#   'morning',
#   ',',
#   'the',
#   'police',
#   'let',
#   'the',
#   'women',
#   'go',
#   'with',
#   'a',
#   'caution',
#   '.',
#   '#Billy',
#   'and',
#   '#Alfie',
#   'are',
#   'locked',
#   'in',
#   'another',
#   'cell',
#   '.',
#   '#Billy',
#   'talks',
#   'about',
#   'the',
#   'horrors',
#   '#Billy',
#   'experienced',
#   'in',
#   'care',
#   '.',
#   'An',
#   'officer',
#   'tells',
#   '#Billy',
#   'they',
#   '’re',
#   'not',
#   'going',
#   'to',
#   'press',
#   'charges',
#   '.',
#   '#Alfie',
#   '’s',
#   'frustrated',
#   'when',
#   'this',
#   'does',
#   'n’t',
#   'cheer',
#   '#Billy',
#   'up',
#   '.',
#   '#Billy',
#   'has',
#   'a',
#   'panic',
#   'attack',
#   'and',
#   '#Alfie',
#   'calmly',
#   'talks',
#   '#Billy',
#   'through',
#   'it',
#   '.',
#   '#Billy',
#   'thanks',
#   '#Alfie',
#   'and',
#   'remembers',
#   '#Julie',
#   'used',
#   'to',
#   'calm',
#   '#Billy',
#   'down',
#   'like',
#   'that',
#   '.',
#   '#Billy',
#   'admits',
#   '#Billy',
#   'always',
#   'hated',
#   '#Alfie',
#   ',',
#   'especially',
#   'when',
#   '#Billy',
#   'was',
#   'with',
#   'Little',
#   'Mo.',
#   '#Billy',
#   '’s',
#   'sure',
#   '#Alfie',
#   'will',
#   'always',
#   'be',
#   'better',
#   'off',
#   'than',
#   '#Billy',
#   ',',
#   'until',
#   '#Alfie',
#   'admits',
#   '#Kat',
#   '’s',
#   'baby',
#   'is',
#   'n’t',
#   '#Billy',
#   '.',
#   '#Billy',
#   'assures',
#   '#Alfie',
#   'the',
#   'baby',
#   '’s',
#   'lucky',
#   'to',
#   'have',
#   '#Billy',
#   '.',
#   'Later',
#   ',',
#   '#Billy',
#   'calls',
#   '#Julie',
#   '.',
#   '#Billy',
#   '’s',
#   'terrified',
#   ',',
#   '#Billy',
#   'does',
#   'n’t',
#   'know',
#   'what',
#   'to',
#   'do',
#   'with',
#   '~Lily',
#   '.',
#   '#Billy',
#   'asks',
#   '#Whitney',
#   'to',
#   'look',
#   'after',
#   'the',
#   'baby',
#   ',',
#   '#Billy',
#   'ca',
#   'n’t',
#   'do',
#   'it',
#   '.',
#   'Later',
#   ',',
#   'when',
#   '#Billy',
#   '’s',
#   'out',
#   'of',
#   'the',
#   'room',
#   ',',
#   '#Whitney',
#   'leaves',
#   '.',
#   '#Billy',
#   'finds',
#   'a',
#   'note',
#   'on',
#   '~Lily',
#   '–',
#   '‘',
#   'you',
#   'can',
#   '’',
#   '.',
#   'Anxious',
#   ',',
#   'after',
#   'discovering',
#   'there',
#   'was',
#   'no',
#   'answer',
#   'when',
#   'the',
#   'police',
#   'called',
#   '#Billy',
#   ',',
#   'Stacey',
#   'and',
#   'Janine',
#   'rush',
#   'home',
#   '.',
#   'They',
#   'find',
#   '~Lily',
#   'asleep',
#   'with',
#   '#Billy',
#   'father',
#   '#Billy',
#   'lying',
#   'next',
#   'to',
#   '~Lily',
#   '.',
#   '#Billy',
#   'tells',
#   'them',
#   '#Billy',
#   'does',
#   'n’t',
#   'care',
#   'what',
#   'either',
#   'of',
#   'them',
#   'say',
#   ',',
#   '#Billy',
#   '’s',
#   'doing',
#   'this',
#   '.'],
#  ['@Ryan',
#   'remains',
#   'adamant',
#   'that',
#   '@Ryan',
#   'wants',
#   'to',
#   'be',
#   'a',
#   'father',
#   'to',
#   'Lily',
#   ',',
#   'much',
#   'to',
#   '@Janine',
#   '’s',
#   'displeasure',
#   '.',
#   '@Ryan',
#   'grows',
#   'frustrated',
#   'when',
#   '@Ryan',
#   'attempts',
#   'to',
#   'see',
#   '~Lily',
#   'are',
#   'thwarted',
#   'by',
#   'the',
#   'Slaters',
#   '.',
#   'Feeling',
#   'for',
#   '@Ryan',
#   ',',
#   '@Janine',
#   'decides',
#   'to',
#   'intervene',
#   '.',
#   'Having',
#   'researched',
#   'the',
#   'official',
#   'channels',
#   'for',
#   '@Ryan',
#   'to',
#   'gain',
#   'access',
#   'to',
#   '~Lily',
#   ',',
#   '@Janine',
#   'presents',
#   '@Janine',
#   'findings',
#   'to',
#   'a',
#   'dismayed',
#   'Stacey',
#   '.',
#   'With',
#   '@Ryan',
#   'unwilling',
#   'to',
#   'back',
#   'down',
#   ',',
#   'Stacey',
#   'relents',
#   'that',
#   '@Ryan',
#   'can',
#   'be',
#   'involved',
#   ',',
#   'provided',
#   '@Ryan',
#   'pays',
#   'child',
#   'maintenance',
#   '.',
#   '@Ryan',
#   'sets',
#   'about',
#   'finding',
#   'another',
#   'job',
#   'in',
#   'order',
#   'to',
#   'raise',
#   'the',
#   'maintenance',
#   'funds',
#   '.',
#   'Having',
#   'sought',
#   'work',
#   'at',
#   'the',
#   'Arches',
#   ',',
#   '@Ryan',
#   'returns',
#   'to',
#   'Stacey',
#   'to',
#   'visit',
#   '~Lily',
#   '.',
#   'Having',
#   'witnessed',
#   '@Ryan',
#   'and',
#   'Stacey',
#   'together',
#   'with',
#   'their',
#   'daughter',
#   ',',
#   '#Kat',
#   'is',
#   'convinced',
#   'that',
#   'Stacey',
#   'fancies',
#   '@Ryan',
#   'and',
#   'that',
#   'they',
#   'should',
#   'make',
#   'a',
#   'family',
#   '.',
#   'Stacey',
#   '’s',
#   'dismissive',
#   ';',
#   'she',
#   'does',
#   'n’t',
#   'want',
#   'to',
#   'wreck',
#   'another',
#   'marriage',
#   ',',
#   'but',
#   '#Kat',
#   'deviously',
#   'assures',
#   'her',
#   'that',
#   'she',
#   '’ll',
#   'take',
#   'care',
#   'of',
#   'it',
#   '.',
#   'With',
#   'the',
#   'deadline',
#   'looming',
#   'for',
#   'paying',
#   'the',
#   'Vic',
#   'rent',
#   ',',
#   '#Alfie',
#   'avoids',
#   'Phil',
#   '.',
#   '#Alfie',
#   'assures',
#   '#Kat',
#   'that',
#   '#Alfie',
#   'has',
#   'everything',
#   'under',
#   'control',
#   '.',
#   '#Alfie',
#   'decides',
#   'to',
#   'get',
#   'involved',
#   'in',
#   '#Jack',
#   '’s',
#   'poker',
#   'night',
#   'in',
#   'an',
#   'effort',
#   'to',
#   'raise',
#   'funds',
#   '.',
#   'The',
#   'game',
#   'begins',
#   ',',
#   'with',
#   '#Jack',
#   ',',
#   'Alfie',
#   ',',
#   'Max',
#   'and',
#   'Patrick',
#   'unimpressed',
#   'when',
#   '#Roxy',
#   'and',
#   'Christian',
#   'arrive',
#   'to',
#   'join',
#   'in',
#   '.',
#   'With',
#   'everyone',
#   'else',
#   'out',
#   'of',
#   'the',
#   'game',
#   ',',
#   '#Alfie',
#   'and',
#   '#Roxy',
#   'are',
#   'left',
#   'facing',
#   'off',
#   '.',
#   'As',
#   'the',
#   'stakes',
#   'get',
#   'increasingly',
#   'high',
#   'with',
#   'both',
#   'parties',
#   'putting',
#   'in',
#   'all',
#   'their',
#   'money',
#   ',',
#   'a',
#   'quietly',
#   'confident',
#   '#Alfie',
#   'reveals',
#   'his',
#   'hand',
#   '.',
#   'He',
#   '’s',
#   'devastated',
#   'when',
#   '#Roxy',
#   'trumps',
#   'him',
#   'with',
#   'a',
#   'straight',
#   'flush',
#   'and',
#   'pockets',
#   'all',
#   'the',
#   'winnings',
#   '.',
#   'Unable',
#   'to',
#   'face',
#   '#Billy',
#   '’s',
#   'death',
#   ',',
#   'an',
#   'increasingly',
#   'fraught',
#   'Carol',
#   'begins',
#   'to',
#   'unravel',
#   '.',
#   'Taking',
#   'out',
#   'her',
#   'anguish',
#   'on',
#   'the',
#   'family',
#   ',',
#   'she',
#   'brands',
#   'Jim',
#   'a',
#   'racist',
#   '.',
#   'When',
#   'Morgan',
#   'spills',
#   'ketchup',
#   'on',
#   '#Billy',
#   '’s',
#   'jumper',
#   ',',
#   '#Liam',
#   'takes',
#   'the',
#   'blame',
#   '.',
#   'At',
#   'breaking',
#   'point',
#   ',',
#   'a',
#   'furious',
#   'Carol',
#   'lashes',
#   'out',
#   ';',
#   'hitting',
#   '#Liam',
#   'across',
#   'the',
#   'head',
#   '.'],
#  ['With',
#   '#Liam',
#   'sporting',
#   'a',
#   'cut',
#   'on',
#   '#Liam',
#   'head',
#   ',',
#   '#Carol',
#   '’s',
#   'wracked',
#   'with',
#   'guilt',
#   'for',
#   'having',
#   'struck',
#   '#Liam',
#   '.',
#   '#Carol',
#   'organises',
#   'a',
#   'family',
#   'dinner',
#   'in',
#   'an',
#   'effort',
#   'to',
#   'regain',
#   'some',
#   'normality',
#   ',',
#   'but',
#   'as',
#   'one',
#   'by',
#   'one',
#   'the',
#   'family',
#   'cancel',
#   ',',
#   '~Carol’s',
#   '’s',
#   'left',
#   'despondent',
#   '.',
#   'Concerned',
#   'for',
#   '#Carol',
#   'mother',
#   ',',
#   '#Carol',
#   'tries',
#   'to',
#   'impress',
#   'upon',
#   'everyone',
#   'the',
#   'importance',
#   'of',
#   'the',
#   'meal',
#   '.',
#   '~Carol’s',
#   '’s',
#   'touched',
#   'when',
#   'the',
#   'family',
#   'rally',
#   'round',
#   '~Carol’s',
#   'for',
#   'the',
#   'dinner',
#   '.',
#   'The',
#   'atmosphere',
#   'quickly',
#   'changes',
#   'when',
#   '#Carol',
#   'discovers',
#   'the',
#   'gash',
#   'on',
#   '#Liam',
#   '’s',
#   'head',
#   '.',
#   'As',
#   '#Carol',
#   'confesses',
#   ',',
#   'a',
#   'horrified',
#   '#Carol',
#   'berates',
#   '#Carol',
#   '.',
#   '#Carol',
#   'bites',
#   'back',
#   ',',
#   'blaming',
#   '#Carol',
#   'for',
#   '#Billy',
#   '’s',
#   'death',
#   'and',
#   'slamming',
#   '~everyone',
#   'in',
#   'turn',
#   'for',
#   '~everyone',
#   'part',
#   'in',
#   'it',
#   '.',
#   '~everyone',
#   '’re',
#   'shocked',
#   'as',
#   '#Carol',
#   'reveals',
#   'that',
#   '~everyone',
#   '’re',
#   'all',
#   'banned',
#   'from',
#   '#Billy',
#   '’s',
#   'funeral',
#   '.',
#   '@Stacey',
#   'agrees',
#   'to',
#   'let',
#   '@Ryan',
#   'look',
#   'after',
#   '~Lily',
#   ',',
#   'but',
#   'is',
#   'adamant',
#   '@Stacey',
#   'does',
#   'n’t',
#   'want',
#   '@Janine',
#   'involved',
#   '.',
#   '@Janine',
#   'attempts',
#   'to',
#   'play',
#   'the',
#   'role',
#   'of',
#   'adoring',
#   'stepmother',
#   ',',
#   'but',
#   'finds',
#   'it',
#   'a',
#   'struggle',
#   'to',
#   'keep',
#   'up',
#   'the',
#   'pretence',
#   '.',
#   '@Ryan',
#   '’s',
#   'forced',
#   'to',
#   'leave',
#   '~Lily',
#   'with',
#   '@Janine',
#   'when',
#   '~Carol’s',
#   'visits',
#   '#Phil',
#   'for',
#   'a',
#   'job',
#   '.',
#   '@Ryan',
#   'manages',
#   'to',
#   'impress',
#   '#Phil',
#   'by',
#   'offering',
#   '@Ryan',
#   'skills',
#   'in',
#   'the',
#   'car',
#   '-',
#   'nicking',
#   'business',
#   '.',
#   'Discovering',
#   'that',
#   '~Lily',
#   'was',
#   'left',
#   'with',
#   '@Janine',
#   ',',
#   'a',
#   'furious',
#   '@Stacey',
#   'lambasts',
#   '@Ryan',
#   ',',
#   'but',
#   'finds',
#   '~Lily',
#   'disarmed',
#   'when',
#   '@Ryan',
#   'shows',
#   'the',
#   'effort',
#   '@Ryan',
#   '’s',
#   'making',
#   'to',
#   'be',
#   'responsible',
#   'and',
#   'provide',
#   '.',
#   '#Billy',
#   '’s',
#   'bolstered',
#   'when',
#   '#Julie',
#   'helps',
#   'on',
#   'the',
#   'stall',
#   'and',
#   '~they',
#   'make',
#   'a',
#   'great',
#   'team',
#   '.',
#   'As',
#   '~they',
#   'reminisce',
#   'about',
#   '~they',
#   'youths',
#   ',',
#   'talk',
#   'turns',
#   'to',
#   '~they',
#   'son',
#   '.',
#   '#Billy',
#   '’s',
#   'wistful',
#   'about',
#   'him',
#   ',',
#   'but',
#   '#Julie',
#   'maintains',
#   'that',
#   'it',
#   'should',
#   'be',
#   'left',
#   'in',
#   'the',
#   'past',
#   '.',
#   'Alone',
#   'later',
#   ',',
#   '#Billy',
#   'contacts',
#   'the',
#   'adoption',
#   'agency',
#   'in',
#   'search',
#   'of',
#   '#Billy',
#   'son',
#   '.',
#   'With',
#   'the',
#   'Vic',
#   'rent',
#   'due',
#   ',',
#   'a',
#   'panicked',
#   '#Alfie',
#   'desperately',
#   'tries',
#   'to',
#   'raise',
#   'the',
#   'funds',
#   '.',
#   'Having',
#   'been',
#   'unable',
#   'to',
#   'come',
#   'up',
#   'with',
#   'the',
#   'money',
#   ',',
#   '#Alfie',
#   'goes',
#   'to',
#   'face',
#   '#Phil',
#   '.',
#   '#Alfie',
#   '’s',
#   'stunned',
#   'to',
#   'discover',
#   'that',
#   'Roxy',
#   '’s',
#   'paid',
#   'the',
#   'rent',
#   'for',
#   '#Alfie',
#   'as',
#   'a',
#   'goodwill',
#   'gesture',
#   '.']]

# %%
marked_2 = {}
for ep in marked:
    marked_2[ep] = []
    for i, tokens in enumerate(marked[ep]):
        episode_characters = ep_characters[ep]
        tokens_all = ['@' + token if token in query_characters else token for token in tokens ]
        tokens_all = ['#' + token if token in episode_characters else token for token in tokens ]
        marked_2[ep].append(' '.join(tokens_all))

# %%
for ep in marked_2:
    print(ep, marked_2[ep])
# Out:
# 5531550228324592939.mp4 ['#Kat persuades @Stacey and #Jean to come to ~R&R with #Kat and #Kim , leaving #Charlie and #Alfie to look after ~Lily . #Alfie quickly escapes to the barrel store . There , #Alfie fixes the new television to the wall , it falls off and smashes . #Alfie joins the girls in R&R. #Charlie has to pick up Mo and leaves ~Lily with #Pat . ~Lily wo n’t settle so #Pat takes ~Lily for a walk . @Janine accuses @Ryan of wanting to go to ~R&R because ~R&R knew @Stacey would be there . @Ryan denies it and leaves , @Janine stays in the club . #Julie explains that @Janine was moved to another home when pregnant , ~their ba
#Phil keys to #Glenda flat . #Glenda insults #Jane . #Peter is outraged , is #Ian going to let #Glenda talk to #Peter wife like that ? #Ian tells #Peter that #Glenda is bitter because #Glenda wanted ~things to carry on between ~things . #Peter goes to #Glenda ’s flat and warns #Glenda to keep away from #Ian . #Phil lets #Phil into the flat and overhears . #Glenda thinks it was #Peter that pushed #Glenda down the stairs . #Kim leaves the bath running . It overflows and short circuits the electricity , leaving the Truemans in a blackout . Fatboy is worried when #Edward chooses #Edward to sing the solo at the carol concert .', "#Phil 's plan to expose #Glenda has unexpected consequences , while #Peter has a shocking parting shot for #Ian before leaving for good . #Bianca 's decision to take responsibility for #Bianca actions leads to further trouble , and #Kim saves the day at th ...

# %%
sentences = {}
for ep in marked_2:
    sentences[ep] = {'support':[], 'marked':[], 'characters':[], 'queries':[]}
    for i, p in enumerate(marked_2[ep]):
        for j, sentence in enumerate(p.split(' . ')):
            hits = [w[1:] for w in sentence.split(' ') if w[1:] in query_characters]
            if len(hits) > 0:
                sentences[ep]['support'].append(full_text[ep][i].split('.')[j].replace('\n', ' ').strip())
                sentences[ep]['marked'].append(sentence.replace('\n', ' ').strip())
                
                sentences[ep]['characters'].append([w[1:] for w in sentence.split(' ') if w[1:] in episode_characters])
                sentences[ep]['queries'].append(hits)

# %%
sentences['5555360238519252381.mp4']
# Out:
# {'support': ['Pat is shocked to find Janine still in her flat, she said she’d leave last night',
#   'Janine thinks that if Ryan had told the police she would have been arrested',
#   'Janine leaves to find Ryan',
#   'Janine finds Ryan waiting at the flat',
#   'Ryan apologises and says he’ll always love her, gives her a goodbye kiss and leaves',
#   'Janine misinterprets it',
#   'Ryan goes to see Stacey, but she pretends she isn’t interested',
#   'Ryan leaves',
#   'Janine tells Pat that everything is fine with Ryan',
#   'Pat’s happy for her, at the Vic tonight they’ll rub Stacey’s nose in it',
#   'Ryan enters the Vic, and tells Stacey he’s finished with Janine',
#   'Pat walks in, what does Ryan think he’s doing? Ryan declares he’s in love with Stacey',
#   'Stacey tells Ryan she loves him, and kisses him',
#   'Janine stands in the doorway watching, devastated',
#   'Janine stands stunned, watching Ryan kiss Stacey',
#   'Lauren notices that Max is affected by Stacey and Ryan',
#   'Janine quietly slips away in a daze',
#   'Ricky and Pat lead her back to Pat’s house',
#   'Janine breaks out of her comatose state, she’s going home',
#   'Lauren asks Max if he still cares about Stacey',
#   'Max tells Lauren that he’s upset that Stacey moved on so quickly from Bradley, and promises he won’t see her again',
#   'Max goes to see Stacey in the Vic, and accuses her of using him and Bradley to protect herself',
#   'Lauren spots Max with Stacey through the window',
#   'Lauren visits Janine and gives her the mobile phone, just play it',
#   'Janine plays the recording and hears Stacey confess, she killed Archie Mitchell',
#   'Ryan and Stacey apologise to the Slater’s for sneaking around',
#   'Ryan asks Stacey if she really meant it when she said she loved him',
#   'Stacey reassures him, she meant every word',
#   'Jean is initially worried but when Ryan tells her how much her loves Stacey, she softens towards him',
#   "Janine's last desperate stand to expose Stacey doesn't quite go according to plan",
#   'Janine leaves Ryan a message, he’s got until lunchtime then she’s telling the police everything',
#   'Max reassures a panicking Stacey that Janine has no evidence',
#   'Janine corners Lauren, Max steps in',
#   'Throughout\xa0Christmas dinner, Jean watches Stacey closely',
#   'Afterwards Jean questions Stacey',
#   'Distraught, Stacey eventually confesses that she did kill Archie',
#   'Jean takes Lily to the Vic, she doesn’t feel safe leaving her with Stacey',
#   'Ryan tells Janine he doesn’t love her',
#   'Desperate, Janine clings to his leg, but he shakes her off and leaves',
#   'Ryan finds Stacey and insists they need to leave now, he doesn’t care that she killed Archie',
#   'Stacey’s unsure, but Ryan sets off to find a car',
#   'Janine arrives',
#   'Everything she says to Stacey is calculated to increase her feelings of guilt about Bradley’s death, suggesting it should have been Stacey on the roof',
#   'When Stacey tries to leave, Janine grabs a knife, holds it in Stacey’s hand then stabs herself',
#   'Horrified, hands covered in blood, Stacey walks out of the house, passing Jean in the hallway',
#   'Max follows Stacey as she climbs up onto the Vic roof',
#   'Stacey looks down at the Square',
#   'Max manages to convince Stacey not to jump',
#   'Stacey moves to take Max’s hand but slips, Max pulls her to safety',
#   'Max tells Stacey to stay put, he’ll get his car and get Stacey away from the Square',
#   'At Janine’s insistence, Jean phones Ryan',
#   'Janine leaves the Slaters, determined to stop Stacey and Ryan leaving',
#   'She staggers into the pub and tells everyone Stacey tried to kill her',
#   'Stacey returns home and finds Jean with Lily',
#   'Stacey manages to convince Jean she didn’t hurt Janine',
#   'Jean panics, the police are coming! Ryan returns, insisting they have go now, but Stacey stops him - she’s not sure if she loves him',
#   'Upset, Ryan says goodbye to Lily and hands her to Stacey',
#   'Tearful, Stacey and Jean say goodbye',
#   'Ronnie and Roxy stop Stacey',
#   'Stacey tells them she did kill Archie',
#   'Roxy’s furious, but Ronnie holds her back and tells Stacey to go',
#   'Max and Stacey drive away',
#   'Janine staggers out of the Vic as the police arrive',
#   'She tells them Stacey Slater tried to kill her',
#   'Janine appeals to Ryan but he ignores her',
#   'Max and Stacey arrive at the airport',
#   'Max admits he still loves Stacey and suggests he comes with her',
#   'They kiss but Stacey quickly pulls away',
#   'They part, Max drives home to the Square as Stacey and Lily sit on a plane, looking out at the lights of London as they fly to safety',
#   'Over Christmas Dinner, Shirley tells Roxy that Janine accused Stacey of killing Archie',
#   'Lauren’s upset, it’s all her fault! Roxy’s aghast when Ronnie allows Stacey to leave with Max',
#   'After Ronnie’s visit, Tanya concludes Max is still having an affair with Stacey',
#   'Whitney invites Ryan to stay for Christmas Dinner',
#   "Janine recovers from the dramatic events of Christmas Day while the Square deals with the fallout from Stacey's departure"],
#  'marked': ['#Pat is shocked to find @Janine still in @Janine flat , @Janine said she ’d leave last night',
#   '@Janine thinks that if @Ryan had told the police @Janine would have been arrested',
#   '@Janine leaves to find @Ryan',
#   '@Janine finds @Ryan waiting at the flat',
#   '@Ryan apologises and says @Ryan ’ll always love @Ryan , gives @Ryan a goodbye kiss and leaves',
#   '@Janine misinterprets it',
#   '@Ryan goes to see @Stacey , but @Stacey pretends @Stacey is n’t interested',
#   '@Ryan leaves',
#   '@Janine tells #Pat that everything is fine with @Ryan',
#   '#Pat ’s happy for @Stacey , at the Vic tonight they ’ll rub @Stacey ’s nose in it',
#   '@Ryan enters the Vic , and tells @Stacey he ’s finished with @Janine',
#   '#Pat walks in , what does @Ryan think @Ryan ’s doing ? @Ryan declares @Ryan ’s in love with @Stacey',
#   '@Stacey tells @Ryan @Stacey loves @Ryan , and kisses @Ryan',
#   '@Janine stands in the doorway watching , devastated',
#   '@Janine stands stunned , watching @Ryan kiss @Stacey',
#   '#Lauren notices that #Max is affected by @Stacey and @Ryan',
#   '@Janine quietly slips away in a daze',
#   '#Ricky and #Pat lead @Janine back to #Pat ’s house',
#   '@Janine breaks out of @Janine comatose state , @Janine ’s going home',
#   '#Lauren asks #Max if #Max still cares about @Stacey',
#   '#Max tells #Lauren that #Max ’s upset that @Stacey moved on so quickly from ~Bradley , and promises #Max wo n’t see @Stacey again',
#   '#Max goes to see @Stacey in the Vic , and accuses @Stacey of using #Max and ~Bradley to protect @Stacey',
#   '#Lauren spots #Max with @Stacey through the window',
#   '#Lauren visits @Janine and gives #Lauren the mobile phone , just play it',
#   '@Janine plays the recording and hears @Stacey confess , @Janine killed Archie Mitchell',
#   '@Ryan and @Stacey apologise to the Slater ’s for sneaking around',
#   '@Ryan asks @Stacey if @Stacey really meant it when @Stacey said @Stacey loved @Ryan',
#   '@Stacey reassures @Ryan , @Stacey meant every word',
#   '#Jean is initially worried but when @Ryan tells #Jean how much #Jean loves @Stacey , #Jean softens towards @Ryan',
#   "#Janine 's last desperate stand to expose #Stacey does n't quite go according to plan .",
#   '@Janine leaves @Ryan a message , @Ryan ’s got until lunchtime then @Janine ’s telling the police everything',
#   '#Max reassures a panicking #Stacey that @Janine has no evidence',
#   '@Janine corners #Lauren , #Max steps in',
#   'Throughout \xa0 Christmas dinner , #Jean watches #Stacey closely',
#   'Afterwards #Jean questions #Stacey',
#   'Distraught , #Stacey eventually confesses that @Janine did kill ~Archie',
#   '#Jean takes Lily to the Vic , #Jean does n’t feel safe leaving #Jean with #Stacey',
#   '@Ryan tells @Janine @Ryan does n’t love @Janine',
#   'Desperate , @Janine clings to @Ryan leg , but @Ryan shakes @Janine off and leaves',
#   '@Ryan finds #Stacey and insists they need to leave now , @Ryan does n’t care that she killed ~Archie',
#   '#Stacey ’s unsure , but @Ryan sets off to find a car',
#   '@Janine arrives',
#   'Everything she says to #Stacey is calculated to increase her feelings of guilt about Bradley ’s death , suggesting it should have been #Stacey on the roof',
#   'When #Stacey tries to leave , @Janine grabs a knife , holds it in #Stacey ’s hand then stabs herself',
#   'Horrified , hands covered in blood , #Stacey walks out of the house , passing #Jean in the hallway',
#   '#Max follows #Stacey as she climbs up onto the Vic roof',
#   '#Stacey looks down at the Square',
#   '#Max manages to convince #Stacey not to jump',
#   '#Stacey moves to take #Max ’s hand but slips , #Max pulls her to safety',
#   '#Max tells #Stacey to stay put , #Max ’ll get #Max car and get #Stacey away from the Square',
#   'At @Janine ’s insistence , #Jean phones @Ryan',
#   '@Janine leaves the Slaters , determined to stop #Stacey and @Ryan leaving',
#   '@Janine staggers into the pub and tells everyone #Stacey tried to kill @Janine',
#   '#Stacey returns home and finds #Jean with ~Lily',
#   '#Stacey manages to convince #Jean she did n’t hurt @Janine',
#   '#Jean panics , the police are coming ! @Ryan returns , insisting they have go now , but #Stacey stops ~him - she ’s not sure if she loves ~him',
#   'Upset , @Ryan says ~goodbye to ~Lily and hands ~Lily to #Stacey',
#   'Tearful , #Stacey and #Jean say ~goodbye',
#   '#Ronnie and #Roxy stop #Stacey',
#   '#Stacey tells them she did kill Archie',
#   '#Roxy ’s furious , but #Ronnie holds her back and tells #Stacey to go',
#   '#Max and #Stacey drive away',
#   '@Janine staggers out of the Vic as the police arrive',
#   '@Janine tells them #Stacey Slater tried to kill @Janine',
#   '@Janine appeals to @Ryan but @Ryan ignores @Janine',
#   '#Max and #Stacey arrive at the airport',
#   '#Max admits #Max still loves #Stacey and suggests #Max comes with her',
#   'They kiss but #Stacey quickly pulls away',
#   'They part , #Max drives home to the Square as #Stacey and Lily sit on a plane , looking out at the lights of London as they fly to safety',
#   'Over Christmas Dinner , #Shirley tells #Roxy that @Janine accused #Stacey of killing Archie',
#   '#Lauren ’s upset , it ’s all #Lauren fault ! #Roxy ’s aghast when #Ronnie allows #Stacey to leave with #Max',
#   'After #Ronnie ’s visit , #Tanya concludes #Max is still having an affair with #Stacey',
#   '#Whitney invites #Ryan to stay for Christmas Dinner',
#   "#Janine recovers from the dramatic events of Christmas Day while the Square deals with the fallout from #Stacey 's departure"],
#  'characters': [['Pat', 'Janine', 'Janine', 'Janine'],
#   ['Janine', 'Ryan', 'Janine'],
#   ['Janine', 'Ryan'],
#   ['Janine', 'Ryan'],
#   ['Ryan', 'Ryan', 'Ryan', 'Ryan'],
#   ['Janine'],
#   ['Ryan', 'Stacey', 'Stacey', 'Stacey'],
#   ['Ryan'],
#   ['Janine', 'Pat', 'Ryan'],
#   ['Pat', 'Stacey', 'Stacey'],
#   ['Ryan', 'Stacey', 'Janine'],
#   ['Pat', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Stacey'],
#   ['Stacey', 'Ryan', 'Stacey', 'Ryan', 'Ryan'],
#   ['Janine'],
#   ['Janine', 'Ryan', 'Stacey'],
#   ['Lauren', 'Max', 'Stacey', 'Ryan'],
#   ['Janine'],
#   ['Ricky', 'Pat', 'Janine', 'Pat'],
#   ['Janine', 'Janine', 'Janine'],
#   ['Lauren', 'Max', 'Max', 'Stacey'],
#   ['Max', 'Lauren', 'Max', 'Stacey', 'Max', 'Stacey'],
#   ['Max', 'Stacey', 'Stacey', 'Max', 'Stacey'],
#   ['Lauren', 'Max', 'Stacey'],
#   ['Lauren', 'Janine', 'Lauren'],
#   ['Janine', 'Stacey', 'Janine'],
#   ['Ryan', 'Stacey'],
#   ['Ryan', 'Stacey', 'Stacey', 'Stacey', 'Stacey', 'Ryan'],
#   ['Stacey', 'Ryan', 'Stacey'],
#   ['Jean', 'Ryan', 'Jean', 'Jean', 'Stacey', 'Jean', 'Ryan'],
#   ['Janine', 'Stacey'],
#   ['Janine', 'Ryan', 'Ryan', 'Janine'],
#   ['Max', 'Stacey', 'Janine'],
#   ['Janine', 'Lauren', 'Max'],
#   ['Jean', 'Stacey'],
#   ['Jean', 'Stacey'],
#   ['Stacey', 'Janine'],
#   ['Jean', 'Jean', 'Jean', 'Stacey'],
#   ['Ryan', 'Janine', 'Ryan', 'Janine'],
#   ['Janine', 'Ryan', 'Ryan', 'Janine'],
#   ['Ryan', 'Stacey', 'Ryan'],
#   ['Stacey', 'Ryan'],
#   ['Janine'],
#   ['Stacey', 'Stacey'],
#   ['Stacey', 'Janine', 'Stacey'],
#   ['Stacey', 'Jean'],
#   ['Max', 'Stacey'],
#   ['Stacey'],
#   ['Max', 'Stacey'],
#   ['Stacey', 'Max', 'Max'],
#   ['Max', 'Stacey', 'Max', 'Max', 'Stacey'],
#   ['Janine', 'Jean', 'Ryan'],
#   ['Janine', 'Stacey', 'Ryan'],
#   ['Janine', 'Stacey', 'Janine'],
#   ['Stacey', 'Jean'],
#   ['Stacey', 'Jean', 'Janine'],
#   ['Jean', 'Ryan', 'Stacey'],
#   ['Ryan', 'Stacey'],
#   ['Stacey', 'Jean'],
#   ['Ronnie', 'Roxy', 'Stacey'],
#   ['Stacey'],
#   ['Roxy', 'Ronnie', 'Stacey'],
#   ['Max', 'Stacey'],
#   ['Janine'],
#   ['Janine', 'Stacey', 'Janine'],
#   ['Janine', 'Ryan', 'Ryan', 'Janine'],
#   ['Max', 'Stacey'],
#   ['Max', 'Max', 'Stacey', 'Max'],
#   ['Stacey'],
#   ['Max', 'Stacey'],
#   ['Shirley', 'Roxy', 'Janine', 'Stacey'],
#   ['Lauren', 'Lauren', 'Roxy', 'Ronnie', 'Stacey', 'Max'],
#   ['Ronnie', 'Tanya', 'Max', 'Stacey'],
#   ['Whitney', 'Ryan'],
#   ['Janine', 'Stacey']],
#  'queries': [['Janine', 'Janine', 'Janine'],
#   ['Janine', 'Ryan', 'Janine'],
#   ['Janine', 'Ryan'],
#   ['Janine', 'Ryan'],
#   ['Ryan', 'Ryan', 'Ryan', 'Ryan'],
#   ['Janine'],
#   ['Ryan', 'Stacey', 'Stacey', 'Stacey'],
#   ['Ryan'],
#   ['Janine', 'Ryan'],
#   ['Stacey', 'Stacey'],
#   ['Ryan', 'Stacey', 'Janine'],
#   ['Ryan', 'Ryan', 'Ryan', 'Ryan', 'Stacey'],
#   ['Stacey', 'Ryan', 'Stacey', 'Ryan', 'Ryan'],
#   ['Janine'],
#   ['Janine', 'Ryan', 'Stacey'],
#   ['Stacey', 'Ryan'],
#   ['Janine'],
#   ['Janine'],
#   ['Janine', 'Janine', 'Janine'],
#   ['Stacey'],
#   ['Stacey', 'Stacey'],
#   ['Stacey', 'Stacey', 'Stacey'],
#   ['Stacey'],
#   ['Janine'],
#   ['Janine', 'Stacey', 'Janine'],
#   ['Ryan', 'Stacey'],
#   ['Ryan', 'Stacey', 'Stacey', 'Stacey', 'Stacey', 'Ryan'],
#   ['Stacey', 'Ryan', 'Stacey'],
#   ['Ryan', 'Stacey', 'Ryan'],
#   ['Janine', 'Stacey'],
#   ['Janine', 'Ryan', 'Ryan', 'Janine'],
#   ['Stacey', 'Janine'],
#   ['Janine'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey', 'Janine'],
#   ['Stacey'],
#   ['Ryan', 'Janine', 'Ryan', 'Janine'],
#   ['Janine', 'Ryan', 'Ryan', 'Janine'],
#   ['Ryan', 'Stacey', 'Ryan'],
#   ['Stacey', 'Ryan'],
#   ['Janine'],
#   ['Stacey', 'Stacey'],
#   ['Stacey', 'Janine', 'Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey', 'Stacey'],
#   ['Janine', 'Ryan'],
#   ['Janine', 'Stacey', 'Ryan'],
#   ['Janine', 'Stacey', 'Janine'],
#   ['Stacey'],
#   ['Stacey', 'Janine'],
#   ['Ryan', 'Stacey'],
#   ['Ryan', 'Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Janine'],
#   ['Janine', 'Stacey', 'Janine'],
#   ['Janine', 'Ryan', 'Ryan', 'Janine'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Janine', 'Stacey'],
#   ['Stacey'],
#   ['Stacey'],
#   ['Ryan'],
#   ['Janine', 'Stacey']]}

# %%
pickle.dump(sentences, open('summaries_query_mentions.pickle', 'wb'))

# %%
with open('summaries.txt', 'w') as f:
     for e in sentences:
        f.write(e + '\n')
        f.write('. '.join(s for s in sentences[e]['support']))
        f.write('\n\n')

# %%
summaries = {}
for ep in sentences:
    summaries[ep] = []
    for sen in sentences[ep]['marked']:
        l = []
        for w in sen.split(' '):
            if len(w) == 0: continue
            l.append(w[1:] if w[0] in ['#', '@', '~'] else w)
        summaries[ep].append(' '.join(l))

# %%
sum([len(summaries[ep])  for ep in summaries])
# Out:
# 388

# %%
pickle.dump(summaries, open('query_character_summaries.pickle', 'wb'))

# %%
sum([len(sentences[ep]['support']) for ep in sentences for ep in sentences])
# Out:
# 4268

# %%
counters = {}
for ep in sentences:
    all_chars = []
    all_chars.extend([k for l in sentences[ep]['characters'] for k in l])
    # all_chars.extend([k for l in sentences[ep]['queries'] for k in l])
    counters[ep] = Counter(all_chars).most_common()

# %%
counters
# Out:
# {'5531550228324592939.mp4': [('Ryan', 26),
#   ('Stacey', 24),
#   ('Janine', 20),
#   ('Kat', 7),
#   ('Pat', 5),
#   ('Billy', 4),
#   ('Kim', 2),
#   ('Charlie', 2),
#   ('Alfie', 2),
#   ('Phil', 2),
#   ('Jean', 1),
#   ('Julie', 1),
#   ('Bianca', 1)],
#  '5534228999422914578.mp4': [('Janine', 20),
#   ('Ryan', 20),
#   ('Stacey', 16),
#   ('Kat', 6),
#   ('Pat', 4),
#   ('Alfie', 2),
#   ('Ricky', 1),
#   ('Vanessa', 1),
#   ('Jodie', 1),
#   ('Max', 1),
#   ('Julie', 1),
#   ('Billy', 1)],
#  '5539381671692122744.mp4': [('Stacey', 14),
#   ('Max', 7),
#   ('Lauren', 6),
#   ('Kat', 3),
#   ('Vanessa', 1)],
#  '5542003749222140011.mp4': [('Stacey', 30),
#   ('Lauren', 24),
#   ('Max', 15),
#   ('Ryan', 8),
#   ('Phil', 3),
#   ('Vanessa', 3),
#   ('Janine', 1),
#   ('Abi', 1),
#   ('Jean', 1)],
#  '5544574287152993687.mp4': [('Ryan', 25),
#   ('Janine', 16),
#   ('Kat', 13),
#   ('Stacey', 7),
#   ('Pat', 4),
#   ('Alfie', 3),
#   ('Max', 1),
#   ('Glenda', 1),
#   ('Phil', 1)],
#  '5544620672795594434.mp4': [('Ryan', 25),
#   ('Janine', 16),
#   ('Kat', 13),
#   ('Stacey', 7),
#   ('Pat', 4),
#   ('Alfie', 3),
#   ('Max', 1),
#   ('Glenda', 1),
#   ('Phil', 1)],
#  '5547193787702629969.mp4': [('Stacey', 47),
#   ('Ryan', 26),
#   ('Kat', 10),
#   ('Janine', 9),
#   ('Dot', 6),
#   ('Jane', 4),
#   ('Heather', 2),
#   ('Zainab', 1),
#   ('Lauren', 1),
#   ('Jean', 1),
#   ('Charlie', 1)],
#  '5549784941472309008.mp4': [('Janine', 50),
#   ('Ryan', 44),
#   ('Stacey', 27),
#   ('Pat', 19),
#   ('Kat', 9),
#   ('Jean', 3),
#   ('Alfie', 2),
#   ('Jay', 2),
#   ('Connor', 2),
#   ('Whitney', 2),
#   ('Jane', 2),
#   ('Phil', 1),
#   ('Dot', 1),
#   ('Peter', 1)],
#  '5552368364300855101.mp4': [('Ryan', 24),
#   ('Stacey', 22),
#   ('Janine', 17),
#   ('Julie', 9),
#   ('Ronnie', 4),
#   ('Connor', 3),
#   ('Billy', 3),
#   ('Kat', 3),
#   ('Jay', 2),
#   ('Phil', 2),
#   ('Whitney', 2),
#   ('Pat', 1)],
#  '5555325449284154780.mp4': [('Stacey', 66),
#   ('Janine', 44),
#   ('Ryan', 42),
#   ('Max', 26),
#   ('Jean', 15),
#   ('Lauren', 9),
#   ('Pat', 6),
#   ('Ronnie', 4),
#   ('Roxy', 4),
#   ('Ricky', 1),
#   ('Shirley', 1),
#   ('Tanya', 1),
#   ('Whitney', 1)],
#  '5555360238519252381.mp4': [('Stacey', 66),
#   ('Janine', 44),
#   ('Ryan', 42),
#   ('Max', 26),
#   ('Jean', 15),
#   ('Lauren', 9),
#   ('Pat', 6),
#   ('Ronnie', 4),
#   ('Roxy', 4),
#   ('Ricky', 1),
#   ('Shirley', 1),
#   ('Tanya', 1),
#   ('Whitney', 1)]}

# %%
results =  {}
for ep in counters:
    results[ep] = []
    for first_name, count in counters[ep]:
        if count > 3:
            try:
                full_name = [n for n in d[ep]['characters'] if n.startswith(first_name)][0]
                results[ep].append((full_name, count))
            except:
                print(first_name, ep, d[ep]['characters'])
# Out:
# Stacey 5544574287152993687.mp4 ['Masood Ahmed', 'Jane Beale', 'Ian Beale', 'Zainab Masood', 'Janine Malloy', 'Ryan Malloy', 'Pat Evans', 'Phil Mitchell', 'Glenda Mitchell', 'Shirley Carter', 'Alfie Moon', 'Kat Moon', 'Bianca Butcher', 'Carol Jackson', 'Connor Stanley', 'Patrick Trueman', 'Billy Mitchell', 'Christian Clarke', 'Peter Beale', 'Tamwar Masood', 'Afia Khan', 'Yusef Khan', 'Ricky Butcher', 'Denise Johnson', 'Mo Harris', 'Whitney Dean', 'Jay Brown', 'Vanessa Gold', 'Lauren Branning', 'Max Branning', 'Roxy Mitchell', 'Heather Trott', 'Mr Atherton', 'Bushra Abbasi', 'Maria De Costa', 'Lad']
# Stacey 5544620672795594434.mp4 ['Masood Ahmed', 'Jane Beale', 'Ian Beale', 'Zainab Masood', 'Janine Malloy', 'Ryan Malloy', 'Pat Evans', 'Phil Mitchell', 'Glenda Mitchell', 'Shirley Carter', 'Alfie Moon', 'Kat Moon', 'Bianca Butcher', 'Carol Jackson', 'Connor Stanley', 'Patrick Trueman', 'Billy Mitchell', 'Christian Clarke', 'Peter Beale', 'Tamwar Masood', 'Afia Khan', 'Yusef Khan', 'Ricky Butcher', 'Denise Johnson', 'Mo Harris', 'Whitney Dean', 'Jay Brown', 'Vanessa Gold', 'Lauren Branning', 'Max Branning', 'Roxy Mitchell', 'Heather Trott', 'Mr Atherton', 'Bushra Abbasi', 'Maria de Costa', 'Lad']

# %%
chars = set()
for ep in results:
    for c in [k[0] for k in results[ep]]:
        chars.add(c)
chars
# Out:
# {'Billy Mitchell',
#  'Dot Branning',
#  'Jane Beale',
#  'Janine Malloy',
#  'Jean Slater',
#  'Julie Perkins',
#  'Kat Moon',
#  'Lauren Branning',
#  'Max Branning',
#  'Pat Evans',
#  'Ronnie Branning',
#  'Roxy Mitchell',
#  'Ryan Malloy',
#  'Stacey Branning'}

# %%
results
# Out:
# {'5531550228324592939.mp4': [('Ryan Malloy', 26),
#   ('Stacey Branning', 24),
#   ('Janine Malloy', 20),
#   ('Kat Moon', 7),
#   ('Pat Evans', 5),
#   ('Billy Mitchell', 4),
#   ('Kim Fox', 2),
#   ('Charlie Slater', 2),
#   ('Alfie Moon', 2),
#   ('Phil Mitchell', 2),
#   ('Jean Slater', 1),
#   ('Julie Perkins', 1),
#   ('Bianca Butcher', 1)],
#  '5534228999422914578.mp4': [('Janine Malloy', 20),
#   ('Ryan Malloy', 20),
#   ('Stacey Branning', 16),
#   ('Kat Moon', 6),
#   ('Pat Evans', 4),
#   ('Alfie Moon', 2),
#   ('Ricky Butcher', 1),
#   ('Vanessa Gold', 1),
#   ('Jodie Gold', 1),
#   ('Max Branning', 1),
#   ('Julie Perkins', 1),
#   ('Billy Mitchell', 1)],
#  '5539381671692122744.mp4': [('Stacey Branning', 14),
#   ('Max Branning', 7),
#   ('Lauren Branning', 6),
#   ('Kat Moon', 3),
#   ('Vanessa Gold', 1)],
#  '5542003749222140011.mp4': [('Stacey Branning', 30),
#   ('Lauren Branning', 24),
#   ('Max Branning', 15),
#   ('Ryan Malloy', 8),
#   ('Phil Mitchell', 3),
#   ('Vanessa Gold', 3),
#   ('Janine Butcher', 1),
#   ('Abi Branning', 1),
#   ('Jean Slater', 1)],
#  '5544574287152993687.mp4': [('Ryan Malloy', 25),
#   ('Janine Malloy', 16),
#   ('Kat Moon', 13),
#   ('Pat Evans', 4),
#   ('Alfie Moon', 3),
#   ('Max Branning', 1),
#   ('Glenda Mitchell', 1),
#   ('Phil Mitchell', 1)],
#  '5544620672795594434.mp4': [('Ryan Malloy', 25),
#   ('Janine Malloy', 16),
#   ('Kat Moon', 13),
#   ('Pat Evans', 4),
#   ('Alfie Moon', 3),
#   ('Max Branning', 1),
#   ('Glenda Mitchell', 1),
#   ('Phil Mitchell', 1)],
#  '5547193787702629969.mp4': [('Stacey Branning', 47),
#   ('Ryan Malloy', 26),
#   ('Kat Moon', 10),
#   ('Janine Malloy', 9),
#   ('Dot Branning', 6),
#   ('Jane Beale', 4),
#   ('Heather Trott', 2),
#   ('Zainab Masood', 1),
#   ('Lauren Branning', 1),
#   ('Jean Slater', 1),
#   ('Charlie Slater', 1)],
#  '5549784941472309008.mp4': [('Janine Malloy', 50),
#   ('Ryan Malloy', 44),
#   ('Stacey Branning', 27),
#   ('Pat Evans', 19),
#   ('Kat Moon', 9),
#   ('Jean Slater', 3),
#   ('Alfie Moon', 2),
#   ('Jay Brown', 2),
#   ('Connor Stanley', 2),
#   ('Whitney Dean', 2),
#   ('Jane Beale', 2),
#   ('Phil Mitchell', 1),
#   ('Dot Branning', 1),
#   ('Peter Beale', 1)],
#  '5552368364300855101.mp4': [('Ryan Malloy', 24),
#   ('Stacey Branning', 22),
#   ('Janine Malloy', 17),
#   ('Julie Perkins', 9),
#   ('Ronnie Branning', 4),
#   ('Connor Stanley', 3),
#   ('Billy Mitchell', 3),
#   ('Kat Moon', 3),
#   ('Jay Mitchell', 2),
#   ('Phil Mitchell', 2),
#   ('Whitney Dean', 2),
#   ('Pat Evans', 1)],
#  '5555325449284154780.mp4': [('Stacey Branning', 66),
#   ('Janine Malloy', 44),
#   ('Ryan Malloy', 42),
#   ('Max Branning', 26),
#   ('Jean Slater', 15),
#   ('Lauren Branning', 9),
#   ('Pat Evans', 6),
#   ('Ronnie Branning', 4),
#   ('Roxy Mitchell', 4),
#   ('Ricky Butcher', 1),
#   ('Shirley Carter', 1),
#   ('Tanya Branning', 1),
#   ('Whitney Dean', 1)],
#  '5555360238519252381.mp4': [('Stacey Branning', 66),
#   ('Janine Malloy', 44),
#   ('Ryan Malloy', 42),
#   ('Max Branning', 26),
#   ('Jean Slater', 15),
#   ('Lauren Branning', 9),
#   ('Pat Evans', 6),
#   ('Ronnie Branning', 4),
#   ('Roxy Mitchell', 4),
#   ('Ricky Butcher', 1),
#   ('Shirley Carter', 1),
#   ('Tanya Branning', 1),
#   ('Whitney Dean', 1)]}

# %%
pickle.dump(results, open('coref_results.pickle', 'wb'))

# %%
full_text.count('.')

# %%
text = """Kat persuades Stacey and Jean to come to R&R with her and Kim, leaving Charlie and Alfie to look after Lily. Alfie quickly escapes to the barrel store. There, Alfie fixes the new television to the wall, it falls off and smashes. Alfie joins the girls in R&R. Charlie has to pick up Mo and leaves Lily with Pat. Lily won’t settle so Pat takes her for a walk.
Janine accuses Ryan of wanting to go to R&R because he knew Stacey would be there. Ryan denies it and leaves, Janine stays in the club.
Julie explains that she was moved to another home when pregnant, their baby was taken away a week after she gave birth. Billy’s angry, first saying the baby should have stayed with them, then insisting Julie shouldn’t have told him about their son at all. Julie leaves, telling Billy he hasn’t changed.
Carol ends up in R&R, Billy joins her. The pair get drunk together. Carol cries, Billy tries to kiss her. When Carol rejects his advances, Billy insults her. Billy then unsuccessfully propositions Jean. Stacey realises Billy’s upset her mum, Janine and Kat get drawn into their argument before Alfie steps in. Ricky takes Carol home, Bianca storms to R&R to confront Billy. Giving Lily to Ryan, Pat follows Bianca into the club, worried. Bianca shouts at Billy. When Bianca backs off, Billy says she’s just like all the other ‘scrubbers’ there. Billy then turns on Stacey, who hits him. Janine pulls out a chunk of Stacey’s hair. Kat and Janine hit each other. Billy staggers away from the fight. Someone puts their hand on Billy’s shoulder, he instinctively turns round and hits them - unfortunately it’s a policeman. Roxy’s jealous when Christian brings Syed to R&R. Christian’s furious when Roxy deliberately spikes Syed’s drink."""

# %%
f
doc = nlp(text)

# %%
doc._.has_coref
# Out:
# True

# %%
for c in doc._.coref_clusters:
    for m in c.mentions:
        print(m, m.start, m.end)
# Out:
# Kat 0 1
# her 10 11
# Stacey 2 3
# Stacey 91 92
# Stacey 213 214
# her 218 219
# Stacey 301 302
# R&R 8 9
# R&R 87 88
# he 89 90
# R&R 176 177
# R&R 242 243
# Charlie 15 16
# Charlie 54 55
# Alfie 17 18
# Alfie 23 24
# Alfie 33 34
# Alfie 48 49
# Lily 21 22
# Lily 62 63
# Lily 66 67
# her 73 74
# the new television 35 38
# it 42 43
# Pat 64 65
# Pat 71 72
# Janine 79 80
# Janine 102 103
# she 112 113
# she 129 130
# Janine 221 222
# Janine 295 296
# Janine 307 308
# Ryan 81 82
# Ryan 96 97
# Julie 109 110
# Julie 149 150
# Julie 161 162
# their 121 122
# them 145 146
# their 156 157
# their baby 121 123
# the baby 139 141
# him 154 155
# their son 156 158
# Billy 133 134
# Billy 165 166
# he 166 167
# Billy 178 179
# Billy 191 192
# his 200 201
# Billy 203 204
# Billy 207 208
# Billy then 207 209
# Billy 215 216
# Billy 245 246
# Billy 264 265
# Billy 271 272
# Billy 285 286
# him 293 294
# Billy 312 313
# Billy 324 325
# he 328 329
# Carol 172 173
# her 180 181
# Carol 188 189
# her 195 196
# Carol 198 199
# her 205 206
# Carol 236 237
# her mum, Janine and Kat 218 224
# their 227 228
# Kat 223 224
# Kat 305 306
# Bianca 239 240
# Bianca 254 255
# Bianca 261 262
# Bianca 267 268
# she 273 274
# Roxy 342 343
# Roxy 355 356
# Syed 348 349
# Syed 358 359
