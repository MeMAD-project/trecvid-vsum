# %% [markdown]
# # Segment diarization
#
# This script splits the wavs of each video to segments based on the `facerec_segment` results.

# %%
import os
import numpy as np
import wavefile
import pickle
from SphereDiar.embed import VLAD, amsoftmax_loss
from SphereDiar.meeting_corpus_util import *
from SphereDiar.SphereDiar import *
from librosa.util import frame
from librosa.feature import mfcc
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import scale
from keras.models import load_model
import warnings
#warnings.filterwarnings("ignore", message="Numerical issues were encountered ")
# Out:
# Using TensorFlow backend.
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# Replaced StandardScaler with MinMaxScales because the StandardScaler produces hundreds of warnings about numerical issues. With MinMax there are no numeric issues.

# %%
def fe(s, fs = 16000):
    mfcc_feat = mfcc(s, n_mfcc = 30, sr = fs, n_fft=512, hop_length=160)  
    return MinMaxScaler().fit_transform(mfcc_feat)
    #return scale(mfcc_feat, axis=1)

# %%
model_path = "./SphereDiar/models/current_best.h5"
emb_model = load_model(model_path, custom_objects={'VLAD': VLAD, 'amsoftmax_loss': amsoftmax_loss})
SD = SphereDiar(emb_model)
video_mapping = {"175": "5531550228324592939.mp4",
                 "176": "5534228999422914578.mp4",
                 "177": "5539381671692122744.mp4",
                 "178": "5542003749222140011.mp4",
                 "179": "5544574287152993687.mp4",
                 "180": "5544620672795594434.mp4",
                 "181": "5547193787702629969.mp4",
                 "182": "5549784941472309008.mp4",
                 "183": "5552368364300855101.mp4",
                 "184": "5555325449284154780.mp4",
                 "185": "5555360238519252381.mp4"}
# Out:
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /l/virkkua1/trecvid-vsum/diarization/SphereDiar/embed.py:75: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
seg_dirs = [d.name for d in os.scandir("./data") if d.is_dir() and d.name.startswith("segments")]
seg_dirs.sort()
seg_dirs
# Out:
# ['segments_add1_keep1_cut0.5',
#  'segments_add1_keep1_cut0.7',
#  'segments_add1_keep2_cut0.5',
#  'segments_add1_keep2_cut0.7',
#  'segments_add1_keepall_cut0.5',
#  'segments_add1_keepall_cut0.7',
#  'segments_add2_keep1_cut0.5',
#  'segments_add2_keep1_cut0.7',
#  'segments_add2_keep2_cut0.5',
#  'segments_add2_keep2_cut0.7',
#  'segments_add2_keepall_cut0.5',
#  'segments_add2_keepall_cut0.7']

# %%
failed = []
for d in seg_dirs:
    print(f"Dealing with dir {d} next.")
    results = {"5531550228324592939.mp4": [],
               "5534228999422914578.mp4": [],
               "5539381671692122744.mp4": [],
               "5542003749222140011.mp4": [],
               "5544574287152993687.mp4": [],
               "5544620672795594434.mp4": [],
               "5547193787702629969.mp4": [],
               "5549784941472309008.mp4": [],
               "5552368364300855101.mp4": [],
               "5555325449284154780.mp4": [],
               "5555360238519252381.mp4": []}
    datapath = f"./data/{d}"
    wavs = [f.name for f in os.scandir(datapath) if f.name.endswith(".wav")]
    wavs.sort()
    for wavfile in wavs:
        print(f"Diarizing file {wavfile} now.")
        (rate, sig) = wavefile.load(f"{datapath}/{wavfile}")
        signal = sig[0]
        S = np.transpose(frame(signal, int(2000*16), int(500*16)))
        X = list(map(lambda s: fe(s, 16000), S))
        X = np.array(np.swapaxes(X, 1, 2))
        X = X.astype(np.float16)
        num_timesteps = X.shape[1]

        if num_timesteps != 201:
            emb_model.layers.pop(0)
            new_input = Input(batch_shape=(None, num_timesteps, 30))
            new_output = emb_model(new_input)
            emb_model = Model(new_input, new_output)

        embs = emb_model.predict(X)
        try:
            SD.cluster(rounds=10, clust_range=[2, 8], num_cores = -2, embeddings=embs)
            spk_labels = SD.speaker_labels_
        except ValueError:
            spk_labels = []
            failed.append(f"{datapath}/{wavfile}")
        short_name = wavfile[:3]
        long_name = video_mapping[short_name]
        results[long_name].append((wavfile, spk_labels))
    print("Saving results to a pickle.")
    pickle.dump(results, open(f"{datapath}/segmented_diarization.pickle", 'wb'))
# Out:
# Dealing with dir segments_add1_keep1_cut0.5 next.
# Diarizing file 175_001.wav now.
# Diarizing file 175_002.wav now.
# Diarizing file 175_003.wav now.
# Diarizing file 175_004.wav now.
# Diarizing file 175_005.wav now.
# Diarizing file 175_006.wav now.
# Diarizing file 175_007.wav now.
# Diarizing file 175_008.wav now.
# Diarizing file 175_009.wav now.
# Diarizing file 175_010.wav now.
# Diarizing file 175_011.wav now.
# Diarizing file 175_012.wav now.
# Diarizing file 175_013.wav now.
# Diarizing file 175_014.wav now.
# Diarizing file 175_015.wav now.
# Diarizing file 175_016.wav now.
# Diarizing file 175_017.wav now.
# Diarizing file 175_018.wav now.
# Diarizing file 175_019.wav now.
# Diarizing file 175_020.wav now.
# Diarizing file 175_021.wav now.
# Diarizing file 175_022.wav now.
# Diarizing file 175_023.wav now.
# Diarizing file 175_024.wav now.
# Diarizing file 175_025.wav now.
# Diarizing file 175_026.wav now.
# Diarizing file 175_027.wav now.
# Diarizing file 175_028.wav now.
# Diarizing file 175_029.wav now.
# Diarizing file 175_030.wav now.
# Diarizing file 175_031.wav now.
# Diarizing file 175_032.wav now.
# Diarizing file 175_033.wav now.
# Diarizing file 175_034.wav now.
# Diarizing file 175_035.wav now.
# Diarizing file 175_036.wav now.
# Diarizing file 175_037.wav now.
# Diarizing file 175_038.wav now.
# Diarizing file 175_039.wav now.
# Diarizing file 175_040.wav now.
# Diarizing file 175_041.wav now.
# Diarizing file 175_042.wav now.
# Diarizing file 175_043.wav now.
# Diarizing file 175_044.wav now.
# Diarizing file 175_045.wav now.
# Diarizing file 175_046.wav now.
# Diarizing file 175_047.wav now.
# Diarizing file 175_048.wav now.
# Diarizing file 175_049.wav now.
# Diarizing file 175_050.wav now.
# Diarizing file 175_051.wav now.
# Diarizing file 175_052.wav now.
# Diarizing file 175_053.wav now.
# Diarizing file 175_054.wav now.
# Diarizing file 175_055.wav now.
# Diarizing file 175_056.wav now.
# Diarizing file 175_057.wav now.
# Diarizing file 175_058.wav now.
# Diarizing file 175_059.wav now.
# Diarizing file 175_060.wav now.
# Diarizing file 175_061.wav now.
# Diarizing file 175_062.wav now.
# Diarizing file 175_063.wav now.
# Diarizing file 175_064.wav now.
# Diarizing file 175_065.wav now.
# Diarizing file 175_066.wav now.
# Diarizing file 175_067.wav now.
# Diarizing file 175_068.wav now.
# Diarizing file 175_069.wav now.
# Diarizing file 175_070.wav now.
# Diarizing file 175_071.wav now.
# Diarizing file 175_072.wav now.
# Diarizing file 175_073.wav now.
# Diarizing file 175_074.wav now.
# Diarizing file 175_075.wav now.
# Diarizing file 175_076.wav now.
# Diarizing file 175_077.wav now.
# Diarizing file 175_078.wav now.
# Diarizing file 175_079.wav now.
# Diarizing file 175_080.wav now.
# Diarizing file 175_081.wav now.
# Diarizing file 175_082.wav now.
# Diarizing file 175_083.wav now.
# Diarizing file 175_084.wav now.
# Diarizing file 175_085.wav now.
# Diarizing file 175_086.wav now.
# Diarizing file 175_087.wav now.
# Diarizing file 175_088.wav now.
# Diarizing file 175_089.wav now.
# Diarizing file 175_090.wav now.
# Diarizing file 175_091.wav now.
# Diarizing file 175_092.wav now.
# Diarizing file 175_093.wav now.
# Diarizing file 175_094.wav now.
# Diarizing file 175_095.wav now.
# Diarizing file 175_096.wav now.
# Diarizing file 175_097.wav now.
# Diarizing file 175_098.wav now.
# Diarizing file 175_099.wav now.
# Diarizing file 175_100.wav now.
# Diarizing file 175_101.wav now.
# Diarizing file 175_102.wav now.
# Diarizing file 175_103.wav now.
# Diarizing file 175_104.wav now.
# Diarizing file 176_001.wav now.
# Diarizing file 176_002.wav now.
# Diarizing file 176_003.wav now.
# Diarizing file 176_004.wav now.
# Diarizing file 176_005.wav now.
# Diarizing file 176_006.wav now.
# Diarizing file 176_007.wav now.
# Diarizing file 176_008.wav now.
# Diarizing file 176_009.wav now.
# Diarizing file 176_010.wav now.
# Diarizing file 176_011.wav now.
# Diarizing file 176_012.wav now.
# Diarizing file 176_013.wav now.
# Diarizing file 176_014.wav now.
# Diarizing file 176_015.wav now.
# Diarizing file 176_016.wav now.
# Diarizing file 176_017.wav now.
# Diarizing file 176_018.wav now.
# Diarizing file 176_019.wav now.
# Diarizing file 176_020.wav now.
# Diarizing file 176_021.wav now.
# Diarizing file 176_022.wav now.
# Diarizing file 176_023.wav now.
# Diarizing file 176_024.wav now.
# Diarizing file 176_025.wav now.
# Diarizing file 176_026.wav now.
# Diarizing file 176_027.wav now.
# Diarizing file 176_028.wav now.
# Diarizing file 176_029.wav now.
# Diarizing file 176_030.wav now.
# Diarizing file 176_031.wav now.
# Diarizing file 176_032.wav now.
# Diarizing file 176_033.wav now.
# Diarizing file 176_034.wav now.
# Diarizing file 176_035.wav now.
# Diarizing file 176_036.wav now.
# Diarizing file 176_037.wav now.
# Diarizing file 176_038.wav now.
# Diarizing file 176_039.wav now.
# Diarizing file 176_040.wav now.
# Diarizing file 176_041.wav now.
# Diarizing file 176_042.wav now.
# Diarizing file 176_043.wav now.
# Diarizing file 176_044.wav now.
# Diarizing file 176_045.wav now.
# Diarizing file 176_046.wav now.
# Diarizing file 176_047.wav now.
# Diarizing file 176_048.wav now.
# Diarizing file 176_049.wav now.
# Diarizing file 176_050.wav now.
# Diarizing file 176_051.wav now.
# Diarizing file 176_052.wav now.
# Diarizing file 176_053.wav now.
# Diarizing file 176_054.wav now.
# Diarizing file 176_055.wav now.
# Diarizing file 176_056.wav now.
# Diarizing file 176_057.wav now.
# Diarizing file 176_058.wav now.
# Diarizing file 176_059.wav now.
# Diarizing file 176_060.wav now.
# Diarizing file 176_061.wav now.
# Diarizing file 176_062.wav now.
# Diarizing file 176_063.wav now.
# Diarizing file 176_064.wav now.
# Diarizing file 176_065.wav now.
# Diarizing file 176_066.wav now.
# Diarizing file 176_067.wav now.
# Diarizing file 176_068.wav now.
# Diarizing file 176_069.wav now.
# Diarizing file 176_070.wav now.
# Diarizing file 176_071.wav now.
# Diarizing file 176_072.wav now.
# Diarizing file 176_073.wav now.
# Diarizing file 176_074.wav now.
# Diarizing file 176_075.wav now.
# Diarizing file 176_076.wav now.
# Diarizing file 176_077.wav now.
# Diarizing file 176_078.wav now.
# Diarizing file 176_079.wav now.
# Diarizing file 176_080.wav now.
# Diarizing file 176_081.wav now.
# Diarizing file 176_082.wav now.
# Diarizing file 176_083.wav now.
# Diarizing file 176_084.wav now.
# Diarizing file 176_085.wav now.
# Diarizing file 176_086.wav now.
# Diarizing file 177_001.wav now.
# Diarizing file 177_002.wav now.
# Diarizing file 177_003.wav now.
# Diarizing file 177_004.wav now.
# Diarizing file 177_005.wav now.
# Diarizing file 177_006.wav now.
# Diarizing file 177_007.wav now.
# Diarizing file 177_008.wav now.
# Diarizing file 177_009.wav now.
# Diarizing file 177_010.wav now.
# Diarizing file 177_011.wav now.
# Diarizing file 177_012.wav now.
# Diarizing file 177_013.wav now.
# Diarizing file 177_014.wav now.
# Diarizing file 177_015.wav now.
# Diarizing file 177_016.wav now.
# Diarizing file 177_017.wav now.
# Diarizing file 177_018.wav now.
# Diarizing file 177_019.wav now.
# Diarizing file 177_020.wav now.
# Diarizing file 177_021.wav now.
# Diarizing file 177_022.wav now.
# Diarizing file 177_023.wav now.
# Diarizing file 177_024.wav now.
# Diarizing file 177_025.wav now.
# Diarizing file 177_026.wav now.
# Diarizing file 177_027.wav now.
# Diarizing file 177_028.wav now.
# Diarizing file 177_029.wav now.
# Diarizing file 177_030.wav now.
# Diarizing file 177_031.wav now.
# Diarizing file 177_032.wav now.
# Diarizing file 177_033.wav now.
# Diarizing file 177_034.wav now.
# Diarizing file 177_035.wav now.
# Diarizing file 177_036.wav now.
# Diarizing file 177_037.wav now.
# Diarizing file 177_038.wav now.
# Diarizing file 177_039.wav now.
# Diarizing file 177_040.wav now.
# Diarizing file 177_041.wav now.
# Diarizing file 177_042.wav now.
# Diarizing file 177_043.wav now.
# Diarizing file 177_044.wav now.
# Diarizing file 177_045.wav now.
# Diarizing file 177_046.wav now.
# Diarizing file 177_047.wav now.
# Diarizing file 177_048.wav now.
# Diarizing file 177_049.wav now.
# Diarizing file 177_050.wav now.
# Diarizing file 177_051.wav now.
# Diarizing file 177_052.wav now.
# Diarizing file 177_053.wav now.
# Diarizing file 177_054.wav now.
# Diarizing file 177_055.wav now.
# Diarizing file 177_056.wav now.
# Diarizing file 177_057.wav now.
# Diarizing file 177_058.wav now.
# Diarizing file 177_059.wav now.
# Diarizing file 177_060.wav now.
# Diarizing file 177_061.wav now.
# Diarizing file 177_062.wav now.
# Diarizing file 177_063.wav now.
# Diarizing file 177_064.wav now.
# Diarizing file 177_065.wav now.
# Diarizing file 177_066.wav now.
# Diarizing file 177_067.wav now.
# Diarizing file 177_068.wav now.
# Diarizing file 177_069.wav now.
# Diarizing file 177_070.wav now.
# Diarizing file 177_071.wav now.
# Diarizing file 177_072.wav now.
# Diarizing file 177_073.wav now.
# Diarizing file 177_074.wav now.
# Diarizing file 177_075.wav now.
# Diarizing file 177_076.wav now.
# Diarizing file 177_077.wav now.
# Diarizing file 177_078.wav now.
# Diarizing file 177_079.wav now.
# Diarizing file 177_080.wav now.
# Diarizing file 177_081.wav now.
# Diarizing file 177_082.wav now.
# Diarizing file 177_083.wav now.
# Diarizing file 177_084.wav now.
# Diarizing file 177_085.wav now.
# Diarizing file 178_001.wav now.
# Diarizing file 178_002.wav now.
# Diarizing file 178_003.wav now.
# Diarizing file 178_004.wav now.
# Diarizing file 178_005.wav now.
# Diarizing file 178_006.wav now.
# Diarizing file 178_007.wav now.
# Diarizing file 178_008.wav now.
# Diarizing file 178_009.wav now.
# Diarizing file 178_010.wav now.
# Diarizing file 178_011.wav now.
# Diarizing file 178_012.wav now.
# Diarizing file 178_013.wav now.
# Diarizing file 178_014.wav now.
# Diarizing file 178_015.wav now.
# Diarizing file 178_016.wav now.
# Diarizing file 178_017.wav now.
# Diarizing file 178_018.wav now.
# Diarizing file 178_019.wav now.
# Diarizing file 178_020.wav now.
# Diarizing file 178_021.wav now.
# Diarizing file 178_022.wav now.
# Diarizing file 178_023.wav now.
# Diarizing file 178_024.wav now.
# Diarizing file 178_025.wav now.
# Diarizing file 178_026.wav now.
# Diarizing file 178_027.wav now.
# Diarizing file 178_028.wav now.
# Diarizing file 178_029.wav now.
# Diarizing file 178_030.wav now.
# Diarizing file 178_031.wav now.
# Diarizing file 178_032.wav now.
# Diarizing file 178_033.wav now.
# Diarizing file 178_034.wav now.
# Diarizing file 178_035.wav now.
# Diarizing file 178_036.wav now.
# Diarizing file 178_037.wav now.
# Diarizing file 178_038.wav now.
# Diarizing file 178_039.wav now.
# Diarizing file 178_040.wav now.
# Diarizing file 178_041.wav now.
# Diarizing file 178_042.wav now.
# Diarizing file 178_043.wav now.
# Diarizing file 178_044.wav now.
# Diarizing file 178_045.wav now.
# Diarizing file 178_046.wav now.
# Diarizing file 178_047.wav now.
# Diarizing file 178_048.wav now.
# Diarizing file 178_049.wav now.
# Diarizing file 178_050.wav now.
# Diarizing file 178_051.wav now.
# Diarizing file 178_052.wav now.
# Diarizing file 178_053.wav now.
# Diarizing file 178_054.wav now.
# Diarizing file 178_055.wav now.
# Diarizing file 178_056.wav now.
# Diarizing file 178_057.wav now.
# Diarizing file 178_058.wav now.
# Diarizing file 178_059.wav now.
# Diarizing file 179_001.wav now.
# Diarizing file 179_002.wav now.
# Diarizing file 179_003.wav now.
# Diarizing file 179_004.wav now.
# Diarizing file 179_005.wav now.
# Diarizing file 179_006.wav now.
# Diarizing file 179_007.wav now.
# Diarizing file 179_008.wav now.
# Diarizing file 179_009.wav now.
# Diarizing file 179_010.wav now.
# Diarizing file 179_011.wav now.
# Diarizing file 179_012.wav now.
# Diarizing file 179_013.wav now.
# Diarizing file 179_014.wav now.
# Diarizing file 179_015.wav now.
# Diarizing file 179_016.wav now.
# Diarizing file 179_017.wav now.
# Diarizing file 179_018.wav now.
# Diarizing file 179_019.wav now.
# Diarizing file 179_020.wav now.
# Diarizing file 179_021.wav now.
# Diarizing file 179_022.wav now.
# Diarizing file 179_023.wav now.
# Diarizing file 179_024.wav now.
# Diarizing file 179_025.wav now.
# Diarizing file 179_026.wav now.
# Diarizing file 179_027.wav now.
# Diarizing file 179_028.wav now.
# Diarizing file 179_029.wav now.
# Diarizing file 179_030.wav now.
# Diarizing file 179_031.wav now.
# Diarizing file 179_032.wav now.
# Diarizing file 179_033.wav now.
# Diarizing file 179_034.wav now.
# Diarizing file 179_035.wav now.
# Diarizing file 179_036.wav now.
# Diarizing file 179_037.wav now.
# Diarizing file 179_038.wav now.
# Diarizing file 179_039.wav now.
# Diarizing file 179_040.wav now.
# Diarizing file 179_041.wav now.
# Diarizing file 179_042.wav now.
# Diarizing file 179_043.wav now.
# Diarizing file 179_044.wav now.
# Diarizing file 179_045.wav now.
# Diarizing file 179_046.wav now.
# Diarizing file 179_047.wav now.
# Diarizing file 179_048.wav now.
# Diarizing file 179_049.wav now.
# Diarizing file 179_050.wav now.
# Diarizing file 179_051.wav now.
# Diarizing file 179_052.wav now.
# Diarizing file 179_053.wav now.
# Diarizing file 179_054.wav now.
# Diarizing file 179_055.wav now.
# Diarizing file 179_056.wav now.
# Diarizing file 179_057.wav now.
# Diarizing file 179_058.wav now.
# Diarizing file 179_059.wav now.
# Diarizing file 179_060.wav now.
# Diarizing file 179_061.wav now.
# Diarizing file 179_062.wav now.
# Diarizing file 179_063.wav now.
# Diarizing file 179_064.wav now.
# Diarizing file 179_065.wav now.
# Diarizing file 179_066.wav now.
# Diarizing file 179_067.wav now.
# Diarizing file 179_068.wav now.
# Diarizing file 179_069.wav now.
# Diarizing file 179_070.wav now.
# Diarizing file 180_001.wav now.
# Diarizing file 180_002.wav now.
# Diarizing file 180_003.wav now.
# Diarizing file 180_004.wav now.
# Diarizing file 180_005.wav now.
# Diarizing file 180_006.wav now.
# Diarizing file 180_007.wav now.
# Diarizing file 180_008.wav now.
# Diarizing file 180_009.wav now.
# Diarizing file 180_010.wav now.
# Diarizing file 180_011.wav now.
# Diarizing file 180_012.wav now.
# Diarizing file 180_013.wav now.
# Diarizing file 180_014.wav now.
# Diarizing file 180_015.wav now.
# Diarizing file 180_016.wav now.
# Diarizing file 180_017.wav now.
# Diarizing file 180_018.wav now.
# Diarizing file 180_019.wav now.
# Diarizing file 180_020.wav now.
# Diarizing file 180_021.wav now.
# Diarizing file 180_022.wav now.
# Diarizing file 181_001.wav now.
# Diarizing file 181_002.wav now.
# Diarizing file 181_003.wav now.
# Diarizing file 181_004.wav now.
# Diarizing file 181_005.wav now.
# Diarizing file 181_006.wav now.
# Diarizing file 181_007.wav now.
# Diarizing file 181_008.wav now.
# Diarizing file 181_009.wav now.
# Diarizing file 181_010.wav now.
# Diarizing file 181_011.wav now.
# Diarizing file 181_012.wav now.
# Diarizing file 181_013.wav now.
# Diarizing file 181_014.wav now.
# Diarizing file 181_015.wav now.
# Diarizing file 181_016.wav now.
# Diarizing file 181_017.wav now.
# Diarizing file 181_018.wav now.
# Diarizing file 181_019.wav now.
# Diarizing file 181_020.wav now.
# Diarizing file 181_021.wav now.
# Diarizing file 181_022.wav now.
# Diarizing file 181_023.wav now.
# Diarizing file 181_024.wav now.
# Diarizing file 181_025.wav now.
# Diarizing file 181_026.wav now.
# Diarizing file 181_027.wav now.
# Diarizing file 181_028.wav now.
# Diarizing file 181_029.wav now.
# Diarizing file 181_030.wav now.
# Diarizing file 181_031.wav now.
# Diarizing file 181_032.wav now.
# Diarizing file 181_033.wav now.
# Diarizing file 181_034.wav now.
# Diarizing file 181_035.wav now.
# Diarizing file 181_036.wav now.
# Diarizing file 181_037.wav now.
# Diarizing file 181_038.wav now.
# Diarizing file 181_039.wav now.
# Diarizing file 181_040.wav now.
# Diarizing file 181_041.wav now.
# Diarizing file 181_042.wav now.
# Diarizing file 181_043.wav now.
# Diarizing file 181_044.wav now.
# Diarizing file 181_045.wav now.
# Diarizing file 181_046.wav now.
# Diarizing file 181_047.wav now.
# Diarizing file 181_048.wav now.
# Diarizing file 181_049.wav now.
# Diarizing file 181_050.wav now.
# Diarizing file 181_051.wav now.
# Diarizing file 181_052.wav now.
# Diarizing file 181_053.wav now.
# Diarizing file 181_054.wav now.
# Diarizing file 181_055.wav now.
# Diarizing file 181_056.wav now.
# Diarizing file 181_057.wav now.
# Diarizing file 181_058.wav now.
# Diarizing file 181_059.wav now.
# Diarizing file 181_060.wav now.
# Diarizing file 181_061.wav now.
# Diarizing file 181_062.wav now.
# Diarizing file 181_063.wav now.
# Diarizing file 181_064.wav now.
# Diarizing file 181_065.wav now.
# Diarizing file 181_066.wav now.
# Diarizing file 181_067.wav now.
# Diarizing file 181_068.wav now.
# Diarizing file 181_069.wav now.
# Diarizing file 181_070.wav now.
# Diarizing file 181_071.wav now.
# Diarizing file 181_072.wav now.
# Diarizing file 181_073.wav now.
# Diarizing file 181_074.wav now.
# Diarizing file 181_075.wav now.
# Diarizing file 181_076.wav now.
# Diarizing file 181_077.wav now.
# Diarizing file 181_078.wav now.
# Diarizing file 182_001.wav now.
# Diarizing file 182_002.wav now.
# Diarizing file 182_003.wav now.
# Diarizing file 182_004.wav now.
# Diarizing file 182_005.wav now.
# Diarizing file 182_006.wav now.
# Diarizing file 182_007.wav now.
# Diarizing file 182_008.wav now.
# Diarizing file 182_009.wav now.
# Diarizing file 182_010.wav now.
# Diarizing file 182_011.wav now.
# Diarizing file 182_012.wav now.
# Diarizing file 182_013.wav now.
# Diarizing file 182_014.wav now.
# Diarizing file 182_015.wav now.
# Diarizing file 182_016.wav now.
# Diarizing file 182_017.wav now.
# Diarizing file 182_018.wav now.
# Diarizing file 182_019.wav now.
# Diarizing file 182_020.wav now.
# Diarizing file 182_021.wav now.
# Diarizing file 182_022.wav now.
# Diarizing file 182_023.wav now.
# Diarizing file 182_024.wav now.
# Diarizing file 182_025.wav now.
# Diarizing file 182_026.wav now.
# Diarizing file 182_027.wav now.
# Diarizing file 182_028.wav now.
# Diarizing file 182_029.wav now.
# Diarizing file 182_030.wav now.
# Diarizing file 182_031.wav now.
# Diarizing file 182_032.wav now.
# Diarizing file 182_033.wav now.
# Diarizing file 182_034.wav now.
# Diarizing file 182_035.wav now.
# Diarizing file 182_036.wav now.
# Diarizing file 182_037.wav now.
# Diarizing file 182_038.wav now.
# Diarizing file 182_039.wav now.
# Diarizing file 182_040.wav now.
# Diarizing file 182_041.wav now.
# Diarizing file 182_042.wav now.
# Diarizing file 182_043.wav now.
# Diarizing file 182_044.wav now.
# Diarizing file 182_045.wav now.
# Diarizing file 182_046.wav now.
# Diarizing file 182_047.wav now.
# Diarizing file 182_048.wav now.
# Diarizing file 182_049.wav now.
# Diarizing file 182_050.wav now.
# Diarizing file 182_051.wav now.
# Diarizing file 182_052.wav now.
# Diarizing file 182_053.wav now.
# Diarizing file 182_054.wav now.
# Diarizing file 182_055.wav now.
# Diarizing file 182_056.wav now.
# Diarizing file 182_057.wav now.
# Diarizing file 182_058.wav now.
# Diarizing file 182_059.wav now.
# Diarizing file 182_060.wav now.
# Diarizing file 182_061.wav now.
# Diarizing file 182_062.wav now.
# Diarizing file 182_063.wav now.
# Diarizing file 182_064.wav now.
# Diarizing file 182_065.wav now.
# Diarizing file 182_066.wav now.
# Diarizing file 182_067.wav now.
# Diarizing file 182_068.wav now.
# Diarizing file 182_069.wav now.
# Diarizing file 182_070.wav now.
# Diarizing file 182_071.wav now.
# Diarizing file 182_072.wav now.
# Diarizing file 182_073.wav now.
# Diarizing file 183_001.wav now.
# Diarizing file 183_002.wav now.
# Diarizing file 183_003.wav now.
# Diarizing file 183_004.wav now.
# Diarizing file 183_005.wav now.
# Diarizing file 183_006.wav now.
# Diarizing file 183_007.wav now.
# Diarizing file 183_008.wav now.
# Diarizing file 183_009.wav now.
# Diarizing file 183_010.wav now.
# Diarizing file 183_011.wav now.
# Diarizing file 183_012.wav now.
# Diarizing file 183_013.wav now.
# Diarizing file 183_014.wav now.
# Diarizing file 183_015.wav now.
# Diarizing file 183_016.wav now.
# Diarizing file 183_017.wav now.
# Diarizing file 183_018.wav now.
# Diarizing file 183_019.wav now.
# Diarizing file 183_020.wav now.
# Diarizing file 183_021.wav now.
# Diarizing file 183_022.wav now.
# Diarizing file 183_023.wav now.
# Diarizing file 183_024.wav now.
# Diarizing file 183_025.wav now.
# Diarizing file 183_026.wav now.
# Diarizing file 183_027.wav now.
# Diarizing file 183_028.wav now.
# Diarizing file 183_029.wav now.
# Diarizing file 183_030.wav now.
# Diarizing file 183_031.wav now.
# Diarizing file 183_032.wav now.
# Diarizing file 183_033.wav now.
# Diarizing file 183_034.wav now.
# Diarizing file 183_035.wav now.
# Diarizing file 183_036.wav now.
# Diarizing file 183_037.wav now.
# Diarizing file 183_038.wav now.
# Diarizing file 183_039.wav now.
# Diarizing file 183_040.wav now.
# Diarizing file 183_041.wav now.
# Diarizing file 183_042.wav now.
# Diarizing file 183_043.wav now.
# Diarizing file 183_044.wav now.
# Diarizing file 183_045.wav now.
# Diarizing file 183_046.wav now.
# Diarizing file 183_047.wav now.
# Diarizing file 183_048.wav now.
# Diarizing file 183_049.wav now.
# Diarizing file 183_050.wav now.
# Diarizing file 183_051.wav now.
# Diarizing file 183_052.wav now.
# Diarizing file 183_053.wav now.
# Diarizing file 183_054.wav now.
# Diarizing file 183_055.wav now.
# Diarizing file 183_056.wav now.
# Diarizing file 183_057.wav now.
# Diarizing file 183_058.wav now.
# Diarizing file 183_059.wav now.
# Diarizing file 183_060.wav now.
# Diarizing file 183_061.wav now.
# Diarizing file 183_062.wav now.
# Diarizing file 183_063.wav now.
# Diarizing file 183_064.wav now.
# Diarizing file 183_065.wav now.
# Diarizing file 183_066.wav now.
# Diarizing file 183_067.wav now.
# Diarizing file 183_068.wav now.
# Diarizing file 183_069.wav now.
# Diarizing file 183_070.wav now.
# Diarizing file 183_071.wav now.
# Diarizing file 183_072.wav now.
# Diarizing file 183_073.wav now.
# Diarizing file 183_074.wav now.
# Diarizing file 183_075.wav now.
# Diarizing file 183_076.wav now.
# Diarizing file 183_077.wav now.
# Diarizing file 183_078.wav now.
# Diarizing file 183_079.wav now.
# Diarizing file 183_080.wav now.
# Diarizing file 184_001.wav now.
# Diarizing file 184_002.wav now.
# Diarizing file 184_003.wav now.
# Diarizing file 184_004.wav now.
# Diarizing file 184_005.wav now.
# Diarizing file 184_006.wav now.
# Diarizing file 184_007.wav now.
# Diarizing file 184_008.wav now.
# Diarizing file 184_009.wav now.
# Diarizing file 184_010.wav now.
# Diarizing file 184_011.wav now.
# Diarizing file 184_012.wav now.
# Diarizing file 184_013.wav now.
# Diarizing file 184_014.wav now.
# Diarizing file 184_015.wav now.
# Diarizing file 184_016.wav now.
# Diarizing file 184_017.wav now.
# Diarizing file 184_018.wav now.
# Diarizing file 184_019.wav now.
# Diarizing file 184_020.wav now.
# Diarizing file 184_021.wav now.
# Diarizing file 184_022.wav now.
# Diarizing file 184_023.wav now.
# Diarizing file 184_024.wav now.
# Diarizing file 184_025.wav now.
# Diarizing file 184_026.wav now.
# Diarizing file 184_027.wav now.
# Diarizing file 184_028.wav now.
# Diarizing file 184_029.wav now.
# Diarizing file 184_030.wav now.
# Diarizing file 184_031.wav now.
# Diarizing file 184_032.wav now.
# Diarizing file 184_033.wav now.
# Diarizing file 184_034.wav now.
# Diarizing file 184_035.wav now.
# Diarizing file 184_036.wav now.
# Diarizing file 184_037.wav now.
# Diarizing file 184_038.wav now.
# Diarizing file 184_039.wav now.
# Diarizing file 184_040.wav now.
# Diarizing file 184_041.wav now.
# Diarizing file 184_042.wav now.
# Diarizing file 184_043.wav now.
# Diarizing file 184_044.wav now.
# Diarizing file 184_045.wav now.
# Diarizing file 184_046.wav now.
# Diarizing file 184_047.wav now.
# Diarizing file 184_048.wav now.
# Diarizing file 184_049.wav now.
# Diarizing file 184_050.wav now.
# Diarizing file 184_051.wav now.
# Diarizing file 184_052.wav now.
# Diarizing file 184_053.wav now.
# Diarizing file 184_054.wav now.
# Diarizing file 184_055.wav now.
# Diarizing file 184_056.wav now.
# Diarizing file 184_057.wav now.
# Diarizing file 184_058.wav now.
# Diarizing file 184_059.wav now.
# Diarizing file 184_060.wav now.
# Diarizing file 184_061.wav now.
# Diarizing file 184_062.wav now.
# Diarizing file 184_063.wav now.
# Diarizing file 184_064.wav now.
# Diarizing file 184_065.wav now.
# Diarizing file 184_066.wav now.
# Diarizing file 184_067.wav now.
# Diarizing file 184_068.wav now.
# Diarizing file 184_069.wav now.
# Diarizing file 185_001.wav now.
# Diarizing file 185_002.wav now.
# Diarizing file 185_003.wav now.
# Diarizing file 185_004.wav now.
# Diarizing file 185_005.wav now.
# Diarizing file 185_006.wav now.
# Diarizing file 185_007.wav now.
# Diarizing file 185_008.wav now.
# Diarizing file 185_009.wav now.
# Diarizing file 185_010.wav now.
# Diarizing file 185_011.wav now.
# Diarizing file 185_012.wav now.
# Diarizing file 185_013.wav now.
# Diarizing file 185_014.wav now.
# Diarizing file 185_015.wav now.
# Diarizing file 185_016.wav now.
# Diarizing file 185_017.wav now.
# Diarizing file 185_018.wav now.
# Diarizing file 185_019.wav now.
# Diarizing file 185_020.wav now.
# Diarizing file 185_021.wav now.
# Diarizing file 185_022.wav now.
# Diarizing file 185_023.wav now.
# Diarizing file 185_024.wav now.
# Diarizing file 185_025.wav now.
# Diarizing file 185_026.wav now.
# Diarizing file 185_027.wav now.
# Diarizing file 185_028.wav now.
# Diarizing file 185_029.wav now.
# Diarizing file 185_030.wav now.
# Diarizing file 185_031.wav now.
# Diarizing file 185_032.wav now.
# Diarizing file 185_033.wav now.
# Diarizing file 185_034.wav now.
# Diarizing file 185_035.wav now.
# Diarizing file 185_036.wav now.
# Diarizing file 185_037.wav now.
# Diarizing file 185_038.wav now.
# Diarizing file 185_039.wav now.
# Diarizing file 185_040.wav now.
# Diarizing file 185_041.wav now.
# Diarizing file 185_042.wav now.
# Diarizing file 185_043.wav now.
# Diarizing file 185_044.wav now.
# Diarizing file 185_045.wav now.
# Diarizing file 185_046.wav now.
# Diarizing file 185_047.wav now.
# Diarizing file 185_048.wav now.
# Diarizing file 185_049.wav now.
# Diarizing file 185_050.wav now.
# Diarizing file 185_051.wav now.
# Diarizing file 185_052.wav now.
# Diarizing file 185_053.wav now.
# Diarizing file 185_054.wav now.
# Diarizing file 185_055.wav now.
# Diarizing file 185_056.wav now.
# Diarizing file 185_057.wav now.
# Diarizing file 185_058.wav now.
# Diarizing file 185_059.wav now.
# Diarizing file 185_060.wav now.
# Diarizing file 185_061.wav now.
# Diarizing file 185_062.wav now.
# Diarizing file 185_063.wav now.
# Diarizing file 185_064.wav now.
# Diarizing file 185_065.wav now.
# Diarizing file 185_066.wav now.
# Diarizing file 185_067.wav now.
# Saving results to a pickle.
# Dealing with dir segments_add1_keep1_cut0.7 next.
# Diarizing file 175_001.wav now.
# Diarizing file 175_002.wav now.
# Diarizing file 175_003.wav now.
# Diarizing file 175_004.wav now.
# Diarizing file 175_005.wav now.
# Diarizing file 175_006.wav now.
# Diarizing file 175_007.wav now.
# Diarizing file 175_008.wav now.
# Diarizing file 175_009.wav now.
# Diarizing file 175_010.wav now.
# Diarizing file 175_011.wav now.
# Diarizing file 175_012.wav now.
# Diarizing file 175_013.wav now.
# Diarizing file 175_014.wav now.
# Diarizing file 175_015.wav now.
# Diarizing file 175_016.wav now.
# Diarizing file 175_017.wav now.
# Diarizing file 175_018.wav now.
# Diarizing file 175_019.wav now.
# Diarizing file 175_020.wav now.
# Diarizing file 175_021.wav now.
# Diarizing file 175_022.wav now.
# Diarizing file 175_023.wav now.
# Diarizing file 175_024.wav now.
# Diarizing file 175_025.wav now.
# Diarizing file 175_026.wav now.
# Diarizing file 175_027.wav now.
# Diarizing file 175_028.wav now.
# Diarizing file 175_029.wav now.
# Diarizing file 175_030.wav now.
# Diarizing file 175_031.wav now.
# Diarizing file 175_032.wav now.
# Diarizing file 175_033.wav now.
# Diarizing file 175_034.wav now.
# Diarizing file 175_035.wav now.
# Diarizing file 175_036.wav now.
# Diarizing file 175_037.wav now.
# Diarizing file 175_038.wav now.
# Diarizing file 175_039.wav now.
# Diarizing file 175_040.wav now.
# Diarizing file 175_041.wav now.
# Diarizing file 175_042.wav now.
# Diarizing file 175_043.wav now.
# Diarizing file 175_044.wav now.
# Diarizing file 175_045.wav now.
# Diarizing file 175_046.wav now.
# Diarizing file 175_047.wav now.
# Diarizing file 175_048.wav now.
# Diarizing file 175_049.wav now.
# Diarizing file 175_050.wav now.
# Diarizing file 175_051.wav now.
# Diarizing file 175_052.wav now.
# Diarizing file 175_053.wav now.
# Diarizing file 175_054.wav now.
# Diarizing file 175_055.wav now.
# Diarizing file 175_056.wav now.
# Diarizing file 175_057.wav now.
# Diarizing file 175_058.wav now.
# Diarizing file 175_059.wav now.
# Diarizing file 175_060.wav now.
# Diarizing file 175_061.wav now.
# Diarizing file 175_062.wav now.
# Diarizing file 175_063.wav now.
# Diarizing file 175_064.wav now.
# Diarizing file 175_065.wav now.
# Diarizing file 175_066.wav now.
# Diarizing file 175_067.wav now.
# Diarizing file 175_068.wav now.
# Diarizing file 175_069.wav now.
# Diarizing file 175_070.wav now.
# Diarizing file 175_071.wav now.
# Diarizing file 175_072.wav now.
# Diarizing file 175_073.wav now.
# Diarizing file 175_074.wav now.
# Diarizing file 175_075.wav now.
# Diarizing file 175_076.wav now.
# Diarizing file 175_077.wav now.
# Diarizing file 175_078.wav now.
# Diarizing file 175_079.wav now.
# Diarizing file 175_080.wav now.
# Diarizing file 175_081.wav now.
# Diarizing file 175_082.wav now.
# Diarizing file 176_001.wav now.
# Diarizing file 176_002.wav now.
# Diarizing file 176_003.wav now.
# Diarizing file 176_004.wav now.
# Diarizing file 176_005.wav now.
# Diarizing file 176_006.wav now.
# Diarizing file 176_007.wav now.
# Diarizing file 176_008.wav now.
# Diarizing file 176_009.wav now.
# Diarizing file 176_010.wav now.
# Diarizing file 176_011.wav now.
# Diarizing file 176_012.wav now.
# Diarizing file 176_013.wav now.
# Diarizing file 176_014.wav now.
# Diarizing file 176_015.wav now.
# Diarizing file 176_016.wav now.
# Diarizing file 176_017.wav now.
# Diarizing file 176_018.wav now.
# Diarizing file 176_019.wav now.
# Diarizing file 176_020.wav now.
# Diarizing file 176_021.wav now.
# Diarizing file 176_022.wav now.
# Diarizing file 176_023.wav now.
# Diarizing file 176_024.wav now.
# Diarizing file 176_025.wav now.
# Diarizing file 176_026.wav now.
# Diarizing file 176_027.wav now.
# Diarizing file 176_028.wav now.
# Diarizing file 176_029.wav now.
# Diarizing file 176_030.wav now.
# Diarizing file 176_031.wav now.
# Diarizing file 176_032.wav now.
# Diarizing file 176_033.wav now.
# Diarizing file 176_034.wav now.
# Diarizing file 176_035.wav now.
# Diarizing file 176_036.wav now.
# Diarizing file 176_037.wav now.
# Diarizing file 176_038.wav now.
# Diarizing file 176_039.wav now.
# Diarizing file 176_040.wav now.
# Diarizing file 176_041.wav now.
# Diarizing file 176_042.wav now.
# Diarizing file 176_043.wav now.
# Diarizing file 176_044.wav now.
# Diarizing file 176_045.wav now.
# Diarizing file 176_046.wav now.
# Diarizing file 176_047.wav now.
# Diarizing file 176_048.wav now.
# Diarizing file 176_049.wav now.
# Diarizing file 176_050.wav now.
# Diarizing file 177_001.wav now.
# Diarizing file 177_002.wav now.
# Diarizing file 177_003.wav now.
# Diarizing file 177_004.wav now.
# Diarizing file 177_005.wav now.
# Diarizing file 177_006.wav now.
# Diarizing file 177_007.wav now.
# Diarizing file 177_008.wav now.
# Diarizing file 177_009.wav now.
# Diarizing file 177_010.wav now.
# Diarizing file 177_011.wav now.
# Diarizing file 177_012.wav now.
# Diarizing file 177_013.wav now.
# Diarizing file 177_014.wav now.
# Diarizing file 177_015.wav now.
# Diarizing file 177_016.wav now.
# Diarizing file 177_017.wav now.
# Diarizing file 177_018.wav now.
# Diarizing file 177_019.wav now.
# Diarizing file 177_020.wav now.
# Diarizing file 177_021.wav now.
# Diarizing file 177_022.wav now.
# Diarizing file 177_023.wav now.
# Diarizing file 177_024.wav now.
# Diarizing file 177_025.wav now.
# Diarizing file 177_026.wav now.
# Diarizing file 177_027.wav now.
# Diarizing file 177_028.wav now.
# Diarizing file 177_029.wav now.
# Diarizing file 177_030.wav now.
# Diarizing file 177_031.wav now.
# Diarizing file 177_032.wav now.
# Diarizing file 178_001.wav now.
# Diarizing file 178_002.wav now.
# Diarizing file 178_003.wav now.
# Diarizing file 178_004.wav now.
# Diarizing file 178_005.wav now.
# Diarizing file 178_006.wav now.
# Diarizing file 178_007.wav now.
# Diarizing file 178_008.wav now.
# Diarizing file 178_009.wav now.
# Diarizing file 178_010.wav now.
# Diarizing file 178_011.wav now.
# Diarizing file 178_012.wav now.
# Diarizing file 178_013.wav now.
# Diarizing file 178_014.wav now.
# Diarizing file 178_015.wav now.
# Diarizing file 178_016.wav now.
# Diarizing file 178_017.wav now.
# Diarizing file 178_018.wav now.
# Diarizing file 178_019.wav now.
# Diarizing file 178_020.wav now.
# Diarizing file 178_021.wav now.
# Diarizing file 178_022.wav now.
# Diarizing file 178_023.wav now.
# Diarizing file 179_001.wav now.
# Diarizing file 179_002.wav now.
# Diarizing file 179_003.wav now.
# Diarizing file 179_004.wav now.
# Diarizing file 179_005.wav now.
# Diarizing file 179_006.wav now.
# Diarizing file 179_007.wav now.
# Diarizing file 179_008.wav now.
# Diarizing file 179_009.wav now.
# Diarizing file 179_010.wav now.
# Diarizing file 179_011.wav now.
# Diarizing file 179_012.wav now.
# Diarizing file 179_013.wav now.
# Diarizing file 179_014.wav now.
# Diarizing file 179_015.wav now.
# Diarizing file 179_016.wav now.
# Diarizing file 179_017.wav now.
# Diarizing file 179_018.wav now.
# Diarizing file 179_019.wav now.
# Diarizing file 179_020.wav now.
# Diarizing file 179_021.wav now.
# Diarizing file 179_022.wav now.
# Diarizing file 179_023.wav now.
# Diarizing file 179_024.wav now.
# Diarizing file 179_025.wav now.
# Diarizing file 179_026.wav now.
# Diarizing file 179_027.wav now.
# Diarizing file 179_028.wav now.
# Diarizing file 179_029.wav now.
# Diarizing file 179_030.wav now.
# Diarizing file 179_031.wav now.
# Diarizing file 179_032.wav now.
# Diarizing file 180_001.wav now.
# Diarizing file 180_002.wav now.
# Diarizing file 180_003.wav now.
# Diarizing file 180_004.wav now.
# Diarizing file 180_005.wav now.
# Diarizing file 181_001.wav now.
# Diarizing file 181_002.wav now.
# Diarizing file 181_003.wav now.
# Diarizing file 181_004.wav now.
# Diarizing file 181_005.wav now.
# Diarizing file 181_006.wav now.
# Diarizing file 181_007.wav now.
# Diarizing file 181_008.wav now.
# Diarizing file 181_009.wav now.
# Diarizing file 181_010.wav now.
# Diarizing file 181_011.wav now.
# Diarizing file 181_012.wav now.
# Diarizing file 181_013.wav now.
# Diarizing file 181_014.wav now.
# Diarizing file 181_015.wav now.
# Diarizing file 181_016.wav now.
# Diarizing file 181_017.wav now.
# Diarizing file 181_018.wav now.
# Diarizing file 181_019.wav now.
# Diarizing file 181_020.wav now.
# Diarizing file 181_021.wav now.
# Diarizing file 181_022.wav now.
# Diarizing file 181_023.wav now.
# Diarizing file 181_024.wav now.
# Diarizing file 181_025.wav now.
# Diarizing file 181_026.wav now.
# Diarizing file 181_027.wav now.
# Diarizing file 181_028.wav now.
# Diarizing file 181_029.wav now.
# Diarizing file 181_030.wav now.
# Diarizing file 181_031.wav now.
# Diarizing file 181_032.wav now.
# Diarizing file 181_033.wav now.
# Diarizing file 181_034.wav now.
# Diarizing file 181_035.wav now.
# Diarizing file 181_036.wav now.
# Diarizing file 181_037.wav now.
# Diarizing file 181_038.wav now.
# Diarizing file 181_039.wav now.
# Diarizing file 181_040.wav now.
# Diarizing file 181_041.wav now.
# Diarizing file 181_042.wav now.
# Diarizing file 181_043.wav now.
# Diarizing file 181_044.wav now.
# Diarizing file 181_045.wav now.
# Diarizing file 181_046.wav now.
# Diarizing file 181_047.wav now.
# Diarizing file 181_048.wav now.
# Diarizing file 181_049.wav now.
# Diarizing file 181_050.wav now.
# Diarizing file 181_051.wav now.
# Diarizing file 181_052.wav now.
# Diarizing file 181_053.wav now.
# Diarizing file 181_054.wav now.
# Diarizing file 181_055.wav now.
# Diarizing file 181_056.wav now.
# Diarizing file 181_057.wav now.
# Diarizing file 181_058.wav now.
# Diarizing file 181_059.wav now.
# Diarizing file 182_001.wav now.
# Diarizing file 182_002.wav now.
# Diarizing file 182_003.wav now.
# Diarizing file 182_004.wav now.
# Diarizing file 182_005.wav now.
# Diarizing file 182_006.wav now.
# Diarizing file 182_007.wav now.
# Diarizing file 182_008.wav now.
# Diarizing file 182_009.wav now.
# Diarizing file 182_010.wav now.
# Diarizing file 182_011.wav now.
# Diarizing file 182_012.wav now.
# Diarizing file 182_013.wav now.
# Diarizing file 182_014.wav now.
# Diarizing file 182_015.wav now.
# Diarizing file 182_016.wav now.
# Diarizing file 182_017.wav now.
# Diarizing file 182_018.wav now.
# Diarizing file 182_019.wav now.
# Diarizing file 182_020.wav now.
# Diarizing file 182_021.wav now.
# Diarizing file 182_022.wav now.
# Diarizing file 182_023.wav now.
# Diarizing file 182_024.wav now.
# Diarizing file 182_025.wav now.
# Diarizing file 182_026.wav now.
# Diarizing file 182_027.wav now.
# Diarizing file 182_028.wav now.
# Diarizing file 182_029.wav now.
# Diarizing file 182_030.wav now.
# Diarizing file 182_031.wav now.
# Diarizing file 182_032.wav now.
# Diarizing file 182_033.wav now.
# Diarizing file 182_034.wav now.
# Diarizing file 182_035.wav now.
# Diarizing file 182_036.wav now.
# Diarizing file 182_037.wav now.
# Diarizing file 182_038.wav now.
# Diarizing file 182_039.wav now.
# Diarizing file 182_040.wav now.
# Diarizing file 182_041.wav now.
# Diarizing file 182_042.wav now.
# Diarizing file 182_043.wav now.
# Diarizing file 182_044.wav now.
# Diarizing file 182_045.wav now.
# Diarizing file 182_046.wav now.
# Diarizing file 182_047.wav now.
# Diarizing file 182_048.wav now.
# Diarizing file 182_049.wav now.
# Diarizing file 182_050.wav now.
# Diarizing file 182_051.wav now.
# Diarizing file 182_052.wav now.
# Diarizing file 182_053.wav now.
# Diarizing file 182_054.wav now.
# Diarizing file 182_055.wav now.
# Diarizing file 182_056.wav now.
# Diarizing file 182_057.wav now.
# Diarizing file 182_058.wav now.
# Diarizing file 182_059.wav now.
# Diarizing file 182_060.wav now.
# Diarizing file 183_001.wav now.
# Diarizing file 183_002.wav now.
# Diarizing file 183_003.wav now.
# Diarizing file 183_004.wav now.
# Diarizing file 183_005.wav now.
# Diarizing file 183_006.wav now.
# Diarizing file 183_007.wav now.
# Diarizing file 183_008.wav now.
# Diarizing file 183_009.wav now.
# Diarizing file 183_010.wav now.
# Diarizing file 183_011.wav now.
# Diarizing file 183_012.wav now.
# Diarizing file 183_013.wav now.
# Diarizing file 183_014.wav now.
# Diarizing file 183_015.wav now.
# Diarizing file 183_016.wav now.
# Diarizing file 183_017.wav now.
# Diarizing file 183_018.wav now.
# Diarizing file 183_019.wav now.
# Diarizing file 183_020.wav now.
# Diarizing file 183_021.wav now.
# Diarizing file 183_022.wav now.
# Diarizing file 183_023.wav now.
# Diarizing file 183_024.wav now.
# Diarizing file 183_025.wav now.
# Diarizing file 183_026.wav now.
# Diarizing file 183_027.wav now.
# Diarizing file 183_028.wav now.
# Diarizing file 183_029.wav now.
# Diarizing file 183_030.wav now.
# Diarizing file 183_031.wav now.
# Diarizing file 183_032.wav now.
# Diarizing file 183_033.wav now.
# Diarizing file 183_034.wav now.
# Diarizing file 183_035.wav now.
# Diarizing file 183_036.wav now.
# Diarizing file 183_037.wav now.
# Diarizing file 183_038.wav now.
# Diarizing file 183_039.wav now.
# Diarizing file 183_040.wav now.
# Diarizing file 183_041.wav now.
# Diarizing file 183_042.wav now.
# Diarizing file 183_043.wav now.
# Diarizing file 183_044.wav now.
# Diarizing file 183_045.wav now.
# Diarizing file 184_001.wav now.
# Diarizing file 184_002.wav now.
# Diarizing file 184_003.wav now.
# Diarizing file 184_004.wav now.
# Diarizing file 184_005.wav now.
# Diarizing file 184_006.wav now.
# Diarizing file 184_007.wav now.
# Diarizing file 184_008.wav now.
# Diarizing file 184_009.wav now.
# Diarizing file 184_010.wav now.
# Diarizing file 184_011.wav now.
# Diarizing file 184_012.wav now.
# Diarizing file 184_013.wav now.
# Diarizing file 184_014.wav now.
# Diarizing file 184_015.wav now.
# Diarizing file 184_016.wav now.
# Diarizing file 184_017.wav now.
# Diarizing file 184_018.wav now.
# Diarizing file 184_019.wav now.
# Diarizing file 184_020.wav now.
# Diarizing file 184_021.wav now.
# Diarizing file 184_022.wav now.
# Diarizing file 184_023.wav now.
# Diarizing file 184_024.wav now.
# Diarizing file 184_025.wav now.
# Diarizing file 184_026.wav now.
# Diarizing file 184_027.wav now.
# Diarizing file 184_028.wav now.
# Diarizing file 184_029.wav now.
# Diarizing file 184_030.wav now.
# Diarizing file 184_031.wav now.
# Diarizing file 184_032.wav now.
# Diarizing file 184_033.wav now.
# Diarizing file 184_034.wav now.
# Diarizing file 184_035.wav now.
# Diarizing file 184_036.wav now.
# Diarizing file 184_037.wav now.
# Diarizing file 184_038.wav now.
# Diarizing file 184_039.wav now.
# Diarizing file 184_040.wav now.
# Diarizing file 184_041.wav now.
# Diarizing file 184_042.wav now.
# Diarizing file 184_043.wav now.
# Diarizing file 184_044.wav now.
# Diarizing file 184_045.wav now.
# Diarizing file 184_046.wav now.
# Diarizing file 184_047.wav now.
# Diarizing file 184_048.wav now.
# Diarizing file 184_049.wav now.
# Diarizing file 184_050.wav now.
# Diarizing file 184_051.wav now.
# Diarizing file 184_052.wav now.
# Diarizing file 184_053.wav now.
# Diarizing file 184_054.wav now.
# Diarizing file 184_055.wav now.
# Diarizing file 184_056.wav now.
# Diarizing file 184_057.wav now.
# Diarizing file 184_058.wav now.
# Diarizing file 185_001.wav now.
# Diarizing file 185_002.wav now.
# Diarizing file 185_003.wav now.
# Diarizing file 185_004.wav now.
# Diarizing file 185_005.wav now.
# Diarizing file 185_006.wav now.
# Diarizing file 185_007.wav now.
# Diarizing file 185_008.wav now.
# Diarizing file 185_009.wav now.
# Diarizing file 185_010.wav now.
# Diarizing file 185_011.wav now.
# Diarizing file 185_012.wav now.
# Diarizing file 185_013.wav now.
# Diarizing file 185_014.wav now.
# Diarizing file 185_015.wav now.
# Diarizing file 185_016.wav now.
# Diarizing file 185_017.wav now.
# Diarizing file 185_018.wav now.
# Diarizing file 185_019.wav now.
# Diarizing file 185_020.wav now.
# Diarizing file 185_021.wav now.
# Diarizing file 185_022.wav now.
# Diarizing file 185_023.wav now.
# Diarizing file 185_024.wav now.
# Diarizing file 185_025.wav now.
# Diarizing file 185_026.wav now.
# Diarizing file 185_027.wav now.
# Diarizing file 185_028.wav now.
# Diarizing file 185_029.wav now.
# Diarizing file 185_030.wav now.
# Diarizing file 185_031.wav now.
# Diarizing file 185_032.wav now.
# Diarizing file 185_033.wav now.
# Diarizing file 185_034.wav now.
# Diarizing file 185_035.wav now.
# Diarizing file 185_036.wav now.
# Diarizing file 185_037.wav now.
# Diarizing file 185_038.wav now.
# Diarizing file 185_039.wav now.
# Diarizing file 185_040.wav now.
# Diarizing file 185_041.wav now.
# Saving results to a pickle.
# Dealing with dir segments_add1_keep2_cut0.5 next.
# Diarizing file 175_001.wav now.
# Diarizing file 175_002.wav now.
# Diarizing file 175_003.wav now.
# Diarizing file 175_004.wav now.
# Diarizing file 175_005.wav now.
# Diarizing file 175_006.wav now.
# Diarizing file 175_007.wav now.
# Diarizing file 175_008.wav now.
# Diarizing file 175_009.wav now.
# Diarizing file 175_010.wav now.
# Diarizing file 175_011.wav now.
# Diarizing file 175_012.wav now.
# Diarizing file 175_013.wav now.
# Diarizing file 175_014.wav now.
# Diarizing file 175_015.wav now.
# Diarizing file 175_016.wav now.
# Diarizing file 175_017.wav now.
# Diarizing file 175_018.wav now.
# Diarizing file 175_019.wav now.
# Diarizing file 175_020.wav now.
# Diarizing file 175_021.wav now.
# Diarizing file 175_022.wav now.
# Diarizing file 175_023.wav now.
# Diarizing file 175_024.wav now.
# Diarizing file 175_025.wav now.
# Diarizing file 175_026.wav now.
# Diarizing file 175_027.wav now.
# Diarizing file 175_028.wav now.
# Diarizing file 175_029.wav now.
# Diarizing file 175_030.wav now.
# Diarizing file 175_031.wav now.
# Diarizing file 175_032.wav now.
# Diarizing file 175_033.wav now.
# Diarizing file 175_034.wav now.
# Diarizing file 175_035.wav now.
# Diarizing file 175_036.wav now.
# Diarizing file 175_037.wav now.
# Diarizing file 175_038.wav now.
# Diarizing file 175_039.wav now.
# Diarizing file 175_040.wav now.
# Diarizing file 175_041.wav now.
# Diarizing file 175_042.wav now.
# Diarizing file 175_043.wav now.
# Diarizing file 175_044.wav now.
# Diarizing file 175_045.wav now.
# Diarizing file 175_046.wav now.
# Diarizing file 175_047.wav now.
# Diarizing file 175_048.wav now.
# Diarizing file 175_049.wav now.
# Diarizing file 175_050.wav now.
# Diarizing file 175_051.wav now.
# Diarizing file 175_052.wav now.
# Diarizing file 175_053.wav now.
# Diarizing file 175_054.wav now.
# Diarizing file 175_055.wav now.
# Diarizing file 175_056.wav now.
# Diarizing file 175_057.wav now.
# Diarizing file 175_058.wav now.
# Diarizing file 175_059.wav now.
# Diarizing file 175_060.wav now.
# Diarizing file 175_061.wav now.
# Diarizing file 175_062.wav now.
# Diarizing file 175_063.wav now.
# Diarizing file 175_064.wav now.
# Diarizing file 175_065.wav now.
# Diarizing file 175_066.wav now.
# Diarizing file 175_067.wav now.
# Diarizing file 175_068.wav now.
# Diarizing file 175_069.wav now.
# Diarizing file 175_070.wav now.
# Diarizing file 175_071.wav now.
# Diarizing file 175_072.wav now.
# Diarizing file 175_073.wav now.
# Diarizing file 175_074.wav now.
# Diarizing file 175_075.wav now.
# Diarizing file 175_076.wav now.
# Diarizing file 175_077.wav now.
# Diarizing file 175_078.wav now.
# Diarizing file 175_079.wav now.
# Diarizing file 175_080.wav now.
# Diarizing file 175_081.wav now.
# Diarizing file 175_082.wav now.
# Diarizing file 175_083.wav now.
# Diarizing file 175_084.wav now.
# Diarizing file 175_085.wav now.
# Diarizing file 175_086.wav now.
# Diarizing file 175_087.wav now.
# Diarizing file 175_088.wav now.
# Diarizing file 175_089.wav now.
# Diarizing file 176_001.wav now.
# Diarizing file 176_002.wav now.
# Diarizing file 176_003.wav now.
# Diarizing file 176_004.wav now.
# Diarizing file 176_005.wav now.
# Diarizing file 176_006.wav now.
# Diarizing file 176_007.wav now.
# Diarizing file 176_008.wav now.
# Diarizing file 176_009.wav now.
# Diarizing file 176_010.wav now.
# Diarizing file 176_011.wav now.
# Diarizing file 176_012.wav now.
# Diarizing file 176_013.wav now.
# Diarizing file 176_014.wav now.
# Diarizing file 176_015.wav now.
# Diarizing file 176_016.wav now.
# Diarizing file 176_017.wav now.
# Diarizing file 176_018.wav now.
# Diarizing file 176_019.wav now.
# Diarizing file 176_020.wav now.
# Diarizing file 176_021.wav now.
# Diarizing file 176_022.wav now.
# Diarizing file 176_023.wav now.
# Diarizing file 176_024.wav now.
# Diarizing file 176_025.wav now.
# Diarizing file 176_026.wav now.
# Diarizing file 176_027.wav now.
# Diarizing file 176_028.wav now.
# Diarizing file 176_029.wav now.
# Diarizing file 176_030.wav now.
# Diarizing file 176_031.wav now.
# Diarizing file 176_032.wav now.
# Diarizing file 176_033.wav now.
# Diarizing file 176_034.wav now.
# Diarizing file 176_035.wav now.
# Diarizing file 176_036.wav now.
# Diarizing file 176_037.wav now.
# Diarizing file 176_038.wav now.
# Diarizing file 176_039.wav now.
# Diarizing file 176_040.wav now.
# Diarizing file 176_041.wav now.
# Diarizing file 176_042.wav now.
# Diarizing file 176_043.wav now.
# Diarizing file 176_044.wav now.
# Diarizing file 176_045.wav now.
# Diarizing file 176_046.wav now.
# Diarizing file 176_047.wav now.
# Diarizing file 176_048.wav now.
# Diarizing file 176_049.wav now.
# Diarizing file 176_050.wav now.
# Diarizing file 176_051.wav now.
# Diarizing file 176_052.wav now.
# Diarizing file 176_053.wav now.
# Diarizing file 176_054.wav now.
# Diarizing file 176_055.wav now.
# Diarizing file 176_056.wav now.
# Diarizing file 176_057.wav now.
# Diarizing file 176_058.wav now.
# Diarizing file 176_059.wav now.
# Diarizing file 176_060.wav now.
# Diarizing file 176_061.wav now.
# Diarizing file 176_062.wav now.
# Diarizing file 176_063.wav now.
# Diarizing file 176_064.wav now.
# Diarizing file 176_065.wav now.
# Diarizing file 176_066.wav now.
# Diarizing file 176_067.wav now.
# Diarizing file 176_068.wav now.
# Diarizing file 176_069.wav now.
# Diarizing file 176_070.wav now.
# Diarizing file 176_071.wav now.
# Diarizing file 176_072.wav now.
# Diarizing file 177_001.wav now.
# Diarizing file 177_002.wav now.
# Diarizing file 177_003.wav now.
# Diarizing file 177_004.wav now.
# Diarizing file 177_005.wav now.
# Diarizing file 177_006.wav now.
# Diarizing file 177_007.wav now.
# Diarizing file 177_008.wav now.
# Diarizing file 177_009.wav now.
# Diarizing file 177_010.wav now.
# Diarizing file 177_011.wav now.
# Diarizing file 177_012.wav now.
# Diarizing file 177_013.wav now.
# Diarizing file 177_014.wav now.
# Diarizing file 177_015.wav now.
# Diarizing file 177_016.wav now.
# Diarizing file 177_017.wav now.
# Diarizing file 177_018.wav now.
# Diarizing file 177_019.wav now.
# Diarizing file 177_020.wav now.
# Diarizing file 177_021.wav now.
# Diarizing file 177_022.wav now.
# Diarizing file 177_023.wav now.
# Diarizing file 177_024.wav now.
# Diarizing file 177_025.wav now.
# Diarizing file 177_026.wav now.
# Diarizing file 177_027.wav now.
# Diarizing file 177_028.wav now.
# Diarizing file 177_029.wav now.
# Diarizing file 177_030.wav now.
# Diarizing file 177_031.wav now.
# Diarizing file 177_032.wav now.
# Diarizing file 177_033.wav now.
# Diarizing file 177_034.wav now.
# Diarizing file 177_035.wav now.
# Diarizing file 177_036.wav now.
# Diarizing file 177_037.wav now.
# Diarizing file 177_038.wav now.
# Diarizing file 177_039.wav now.
# Diarizing file 177_040.wav now.
# Diarizing file 177_041.wav now.
# Diarizing file 177_042.wav now.
# Diarizing file 177_043.wav now.
# Diarizing file 177_044.wav now.
# Diarizing file 177_045.wav now.
# Diarizing file 177_046.wav now.
# Diarizing file 177_047.wav now.
# Diarizing file 177_048.wav now.
# Diarizing file 177_049.wav now.
# Diarizing file 177_050.wav now.
# Diarizing file 177_051.wav now.
# Diarizing file 177_052.wav now.
# ...
# Diarizing file 182_046.wav now.
# Diarizing file 182_047.wav now.
# Diarizing file 182_048.wav now.
# Diarizing file 182_049.wav now.
# Diarizing file 182_050.wav now.
# Diarizing file 182_051.wav now.
# Diarizing file 182_052.wav now.
# Diarizing file 182_053.wav now.
# Diarizing file 182_054.wav now.
# Diarizing file 182_055.wav now.
# Diarizing file 182_056.wav now.
# Diarizing file 182_057.wav now.
# Diarizing file 182_058.wav now.
# Diarizing file 182_059.wav now.
# Diarizing file 182_060.wav now.
# Diarizing file 182_061.wav now.
# Diarizing file 182_062.wav now.
# Diarizing file 182_063.wav now.
# Diarizing file 182_064.wav now.
# Diarizing file 182_065.wav now.
# Diarizing file 182_066.wav now.
# Diarizing file 182_067.wav now.
# Diarizing file 182_068.wav now.
# Diarizing file 182_069.wav now.
# Diarizing file 182_070.wav now.
# Diarizing file 182_071.wav now.
# Diarizing file 182_072.wav now.
# Diarizing file 182_073.wav now.
# Diarizing file 182_074.wav now.
# Diarizing file 182_075.wav now.
# Diarizing file 182_076.wav now.
# Diarizing file 182_077.wav now.
# Diarizing file 182_078.wav now.
# Diarizing file 182_079.wav now.
# Diarizing file 182_080.wav now.
# Diarizing file 182_081.wav now.
# Diarizing file 182_082.wav now.
# Diarizing file 182_083.wav now.
# Diarizing file 182_084.wav now.
# Diarizing file 182_085.wav now.
# Diarizing file 182_086.wav now.
# Diarizing file 182_087.wav now.
# Diarizing file 182_088.wav now.
# Diarizing file 182_089.wav now.
# Diarizing file 182_090.wav now.
# Diarizing file 182_091.wav now.
# Diarizing file 182_092.wav now.
# Diarizing file 182_093.wav now.
# Diarizing file 182_094.wav now.
# Diarizing file 182_095.wav now.
# Diarizing file 182_096.wav now.
# Diarizing file 182_097.wav now.
# Diarizing file 182_098.wav now.
# Diarizing file 182_099.wav now.
# Diarizing file 182_100.wav now.
# Diarizing file 182_101.wav now.
# Diarizing file 182_102.wav now.
# Diarizing file 182_103.wav now.
# Diarizing file 182_104.wav now.
# Diarizing file 182_105.wav now.
# Diarizing file 182_106.wav now.
# Diarizing file 182_107.wav now.
# Diarizing file 182_108.wav now.
# Diarizing file 182_109.wav now.
# Diarizing file 182_110.wav now.
# Diarizing file 182_111.wav now.
# Diarizing file 182_112.wav now.
# Diarizing file 183_001.wav now.
# Diarizing file 183_002.wav now.
# Diarizing file 183_003.wav now.
# Diarizing file 183_004.wav now.
# Diarizing file 183_005.wav now.
# Diarizing file 183_006.wav now.
# Diarizing file 183_007.wav now.
# Diarizing file 183_008.wav now.
# Diarizing file 183_009.wav now.
# Diarizing file 183_010.wav now.
# Diarizing file 183_011.wav now.
# Diarizing file 183_012.wav now.
# Diarizing file 183_013.wav now.
# Diarizing file 183_014.wav now.
# Diarizing file 183_015.wav now.
# Diarizing file 183_016.wav now.
# Diarizing file 183_017.wav now.
# Diarizing file 183_018.wav now.
# Diarizing file 183_019.wav now.
# Diarizing file 183_020.wav now.
# Diarizing file 183_021.wav now.
# Diarizing file 183_022.wav now.
# Diarizing file 183_023.wav now.
# Diarizing file 183_024.wav now.
# Diarizing file 183_025.wav now.
# Diarizing file 183_026.wav now.
# Diarizing file 183_027.wav now.
# Diarizing file 183_028.wav now.
# Diarizing file 183_029.wav now.
# Diarizing file 183_030.wav now.
# Diarizing file 183_031.wav now.
# Diarizing file 183_032.wav now.
# Diarizing file 183_033.wav now.
# Diarizing file 183_034.wav now.
# Diarizing file 183_035.wav now.
# Diarizing file 183_036.wav now.
# Diarizing file 183_037.wav now.
# Diarizing file 183_038.wav now.
# Diarizing file 183_039.wav now.
# Diarizing file 183_040.wav now.
# Diarizing file 183_041.wav now.
# Diarizing file 183_042.wav now.
# Diarizing file 183_043.wav now.
# Diarizing file 183_044.wav now.
# Diarizing file 183_045.wav now.
# Diarizing file 183_046.wav now.
# Diarizing file 183_047.wav now.
# Diarizing file 183_048.wav now.
# Diarizing file 183_049.wav now.
# Diarizing file 183_050.wav now.
# Diarizing file 183_051.wav now.
# Diarizing file 183_052.wav now.
# Diarizing file 183_053.wav now.
# Diarizing file 183_054.wav now.
# Diarizing file 183_055.wav now.
# Diarizing file 183_056.wav now.
# Diarizing file 183_057.wav now.
# Diarizing file 183_058.wav now.
# Diarizing file 183_059.wav now.
# Diarizing file 183_060.wav now.
# Diarizing file 183_061.wav now.
# Diarizing file 183_062.wav now.
# Diarizing file 183_063.wav now.
# Diarizing file 183_064.wav now.
# Diarizing file 183_065.wav now.
# Diarizing file 183_066.wav now.
# Diarizing file 183_067.wav now.
# Diarizing file 183_068.wav now.
# Diarizing file 183_069.wav now.
# Diarizing file 183_070.wav now.
# Diarizing file 183_071.wav now.
# Diarizing file 183_072.wav now.
# Diarizing file 183_073.wav now.
# Diarizing file 183_074.wav now.
# Diarizing file 183_075.wav now.
# Diarizing file 183_076.wav now.
# Diarizing file 183_077.wav now.
# Diarizing file 183_078.wav now.
# Diarizing file 183_079.wav now.
# Diarizing file 183_080.wav now.
# Diarizing file 183_081.wav now.
# Diarizing file 183_082.wav now.
# Diarizing file 183_083.wav now.
# Diarizing file 183_084.wav now.
# Diarizing file 183_085.wav now.
# Diarizing file 183_086.wav now.
# Diarizing file 183_087.wav now.
# Diarizing file 183_088.wav now.
# Diarizing file 183_089.wav now.
# Diarizing file 183_090.wav now.
# Diarizing file 183_091.wav now.
# Diarizing file 183_092.wav now.
# Diarizing file 183_093.wav now.
# Diarizing file 183_094.wav now.
# Diarizing file 183_095.wav now.
# Diarizing file 183_096.wav now.
# Diarizing file 183_097.wav now.
# Diarizing file 183_098.wav now.
# Diarizing file 183_099.wav now.
# Diarizing file 183_100.wav now.
# Diarizing file 183_101.wav now.
# Diarizing file 183_102.wav now.
# Diarizing file 183_103.wav now.
# Diarizing file 183_104.wav now.
# Diarizing file 183_105.wav now.
# Diarizing file 183_106.wav now.
# Diarizing file 183_107.wav now.
# Diarizing file 183_108.wav now.
# Diarizing file 184_001.wav now.
# Diarizing file 184_002.wav now.
# Diarizing file 184_003.wav now.
# Diarizing file 184_004.wav now.
# Diarizing file 184_005.wav now.
# Diarizing file 184_006.wav now.
# Diarizing file 184_007.wav now.
# Diarizing file 184_008.wav now.
# Diarizing file 184_009.wav now.
# Diarizing file 184_010.wav now.
# Diarizing file 184_011.wav now.
# Diarizing file 184_012.wav now.
# Diarizing file 184_013.wav now.
# Diarizing file 184_014.wav now.
# Diarizing file 184_015.wav now.
# Diarizing file 184_017.wav now.
# Diarizing file 184_018.wav now.
# Diarizing file 184_019.wav now.
# Diarizing file 184_020.wav now.
# Diarizing file 184_021.wav now.
# Diarizing file 184_022.wav now.
# Diarizing file 184_023.wav now.
# Diarizing file 184_024.wav now.
# Diarizing file 184_025.wav now.
# Diarizing file 184_026.wav now.
# Diarizing file 184_027.wav now.
# Diarizing file 184_028.wav now.
# Diarizing file 184_029.wav now.
# Diarizing file 184_030.wav now.
# Diarizing file 184_031.wav now.
# Diarizing file 184_032.wav now.
# Diarizing file 184_033.wav now.
# Diarizing file 184_034.wav now.
# Diarizing file 184_035.wav now.
# Diarizing file 184_036.wav now.
# Diarizing file 184_037.wav now.
# Diarizing file 184_038.wav now.
# Diarizing file 184_039.wav now.
# Diarizing file 184_040.wav now.
# Diarizing file 184_041.wav now.
# Diarizing file 184_042.wav now.
# Diarizing file 184_043.wav now.
# Diarizing file 184_044.wav now.
# Diarizing file 184_045.wav now.
# Diarizing file 184_046.wav now.
# Diarizing file 184_047.wav now.
# Diarizing file 184_048.wav now.
# Diarizing file 184_049.wav now.
# Diarizing file 184_050.wav now.
# Diarizing file 184_051.wav now.
# Diarizing file 184_052.wav now.
# Diarizing file 184_053.wav now.
# Diarizing file 184_054.wav now.
# Diarizing file 184_055.wav now.
# Diarizing file 184_056.wav now.
# Diarizing file 184_057.wav now.
# Diarizing file 184_058.wav now.
# Diarizing file 184_059.wav now.
# Diarizing file 184_060.wav now.
# Diarizing file 184_061.wav now.
# Diarizing file 184_062.wav now.
# Diarizing file 184_063.wav now.
# Diarizing file 184_064.wav now.
# Diarizing file 184_065.wav now.
# Diarizing file 184_066.wav now.
# Diarizing file 184_067.wav now.
# Diarizing file 184_068.wav now.
# Diarizing file 184_069.wav now.
# Diarizing file 184_070.wav now.
# Diarizing file 184_071.wav now.
# Diarizing file 184_072.wav now.
# Diarizing file 184_073.wav now.
# Diarizing file 184_074.wav now.
# Diarizing file 184_075.wav now.
# Diarizing file 184_076.wav now.
# Diarizing file 184_077.wav now.
# Diarizing file 184_078.wav now.
# Diarizing file 184_079.wav now.
# Diarizing file 184_080.wav now.
# Diarizing file 184_081.wav now.
# Diarizing file 184_082.wav now.
# Diarizing file 184_083.wav now.
# Diarizing file 184_084.wav now.
# Diarizing file 184_085.wav now.
# Diarizing file 184_086.wav now.
# Diarizing file 184_087.wav now.
# Diarizing file 184_089.wav now.
# Diarizing file 184_090.wav now.
# Diarizing file 184_091.wav now.
# Diarizing file 184_092.wav now.
# Diarizing file 184_093.wav now.
# Diarizing file 184_094.wav now.
# Diarizing file 184_095.wav now.
# Diarizing file 184_096.wav now.
# Diarizing file 184_097.wav now.
# Diarizing file 184_098.wav now.
# Diarizing file 184_099.wav now.
# Diarizing file 184_100.wav now.
# Diarizing file 184_101.wav now.
# Diarizing file 184_102.wav now.
# Diarizing file 184_103.wav now.
# Diarizing file 184_104.wav now.
# Diarizing file 184_105.wav now.
# Diarizing file 184_106.wav now.
# Diarizing file 184_107.wav now.
# Diarizing file 184_108.wav now.
# Diarizing file 184_109.wav now.
# Diarizing file 184_110.wav now.
# Diarizing file 184_111.wav now.
# Diarizing file 184_112.wav now.
# Diarizing file 184_113.wav now.
# Diarizing file 184_114.wav now.
# Diarizing file 184_115.wav now.
# Diarizing file 184_116.wav now.
# Diarizing file 184_117.wav now.
# Diarizing file 184_118.wav now.
# Diarizing file 184_119.wav now.
# Diarizing file 184_120.wav now.
# Diarizing file 184_121.wav now.
# Diarizing file 184_122.wav now.
# Diarizing file 184_123.wav now.
# Diarizing file 184_124.wav now.
# Diarizing file 184_125.wav now.
# Diarizing file 184_126.wav now.
# Diarizing file 184_127.wav now.
# Diarizing file 184_128.wav now.
# Diarizing file 184_129.wav now.
# Diarizing file 184_130.wav now.
# Diarizing file 184_131.wav now.
# Diarizing file 184_132.wav now.
# Diarizing file 184_133.wav now.
# Diarizing file 184_134.wav now.
# Diarizing file 184_135.wav now.
# Diarizing file 184_136.wav now.
# Diarizing file 184_137.wav now.
# Diarizing file 184_138.wav now.
# Diarizing file 184_139.wav now.
# Diarizing file 184_140.wav now.
# Diarizing file 184_141.wav now.
# Diarizing file 184_142.wav now.
# Diarizing file 184_143.wav now.
# Diarizing file 184_144.wav now.
# Diarizing file 184_145.wav now.
# Diarizing file 184_146.wav now.
# Diarizing file 185_001.wav now.
# Diarizing file 185_002.wav now.
# Diarizing file 185_003.wav now.
# Diarizing file 185_004.wav now.
# Diarizing file 185_005.wav now.
# Diarizing file 185_006.wav now.
# Diarizing file 185_007.wav now.
# Diarizing file 185_008.wav now.
# Diarizing file 185_009.wav now.
# Diarizing file 185_010.wav now.
# Diarizing file 185_011.wav now.
# Diarizing file 185_012.wav now.
# Diarizing file 185_013.wav now.
# Diarizing file 185_014.wav now.
# Diarizing file 185_015.wav now.
# Diarizing file 185_016.wav now.
# Diarizing file 185_017.wav now.
# Diarizing file 185_018.wav now.
# Diarizing file 185_019.wav now.
# Diarizing file 185_020.wav now.
# Diarizing file 185_021.wav now.
# Diarizing file 185_022.wav now.
# Diarizing file 185_023.wav now.
# Diarizing file 185_024.wav now.
# Diarizing file 185_025.wav now.
# Diarizing file 185_026.wav now.
# Diarizing file 185_027.wav now.
# Diarizing file 185_028.wav now.
# Diarizing file 185_029.wav now.
# Diarizing file 185_030.wav now.
# Diarizing file 185_031.wav now.
# Diarizing file 185_032.wav now.
# Diarizing file 185_033.wav now.
# Diarizing file 185_034.wav now.
# Diarizing file 185_035.wav now.
# Diarizing file 185_036.wav now.
# Diarizing file 185_037.wav now.
# Diarizing file 185_038.wav now.
# Diarizing file 185_039.wav now.
# Diarizing file 185_040.wav now.
# Diarizing file 185_041.wav now.
# Diarizing file 185_042.wav now.
# Diarizing file 185_043.wav now.
# Diarizing file 185_044.wav now.
# Diarizing file 185_045.wav now.
# Diarizing file 185_046.wav now.
# Diarizing file 185_047.wav now.
# Diarizing file 185_048.wav now.
# Diarizing file 185_049.wav now.
# Diarizing file 185_050.wav now.
# Diarizing file 185_051.wav now.
# Diarizing file 185_052.wav now.
# Diarizing file 185_053.wav now.
# Diarizing file 185_054.wav now.
# Diarizing file 185_055.wav now.
# Diarizing file 185_056.wav now.
# Diarizing file 185_057.wav now.
# Diarizing file 185_058.wav now.
# Diarizing file 185_059.wav now.
# Diarizing file 185_060.wav now.
# Diarizing file 185_061.wav now.
# Diarizing file 185_062.wav now.
# Diarizing file 185_063.wav now.
# Diarizing file 185_064.wav now.
# Diarizing file 185_065.wav now.
# Diarizing file 185_066.wav now.
# Diarizing file 185_067.wav now.
# Diarizing file 185_068.wav now.
# Diarizing file 185_069.wav now.
# Diarizing file 185_070.wav now.
# Diarizing file 185_071.wav now.
# Diarizing file 185_072.wav now.
# Diarizing file 185_073.wav now.
# Diarizing file 185_074.wav now.
# Diarizing file 185_075.wav now.
# Diarizing file 185_076.wav now.
# Diarizing file 185_077.wav now.
# Diarizing file 185_078.wav now.
# Diarizing file 185_079.wav now.
# Diarizing file 185_080.wav now.
# Saving results to a pickle.
# Dealing with dir segments_add2_keep1_cut0.5 next.
# Diarizing file 175_001.wav now.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b1a82a339be4> in <module>
#      34         embs = emb_model.predict(X)
#      35         try:
# ---> 36             SD.cluster(rounds=10, clust_range=[2, 8], num_cores = -2, embeddings=embs)
#      37             spk_labels = SD.speaker_labels_
#      38         except ValueError:
#
# /l/virkkua1/trecvid-vsum/diarization/SphereDiar/SphereDiar.py in cluster(self, rounds, clust_range, num_cores, threshold, embeddings)
#     206         # Top Two Silhouettes
#     207         opt_center_num, center_dict = Top2S(embeddings, clust_range = clust_range,
# --> 208                                        rounds = rounds, num_cores = num_cores, threshold = threshold)
#     209         self.centers_ = center_dict
#     210         self.opt_speaker_num_ = opt_center_num
#
# /l/virkkua1/trecvid-vsum/diarization/SphereDiar/SphereDiar.py in Top2S(embeddings, threshold, rounds, clust_range, num_cores)
#     100             round_configs = Parallel(n_jobs=num_cores)(delayed(silh_score)(embeddings,
#     101                                                                              K)
# --> 102                 for K in np.arange(clust_range[0], clust_range[1]))
#     103
#     104             # Update cluster centers, silhouette scores and labels
#
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     538         AsyncResults.get from multiprocessing."""
#     539         try:
# --> 540             return future.result(timeout=timeout)
#     541         except CfTimeoutError:
#     542             raise TimeoutError()
#
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /l/virkkua1/anaconda3/envs/sphere/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
pickle.dump(failed, open("data/failed_diar.pickle", 'wb'))

# %%
#d = os.path.dirname(fails[0])
results = pickle.load(open(f"{d}/segmented_diarization.pickle", 'rb'))

# %%
K = 7
failed = []
for fail in fails:
    if d != os.path.dirname(fail):
        pickle.dump(results, open(f"{d}/segmented_diarization2.pickle", 'wb'))
        d = os.path.dirname(fail)
        results = pickle.load(open(f"{d}/segmented_diarization.pickle", 'rb'))
        
    print(f"Diarizing file {fail} now.")
    (rate, sig) = wavefile.load(f"{fail}")
    signal = sig[0]
    S = np.transpose(frame(signal, int(2000*16), int(500*16)))
    X = list(map(lambda s: fe(s, 16000), S))
    X = np.array(np.swapaxes(X, 1, 2))
    X = X.astype(np.float16)
    num_timesteps = X.shape[1]

    if num_timesteps != 201:
        emb_model.layers.pop(0)
        new_input = Input(batch_shape=(None, num_timesteps, 30))
        new_output = emb_model(new_input)
        emb_model = Model(new_input, new_output)

    embs = emb_model.predict(X)
    try:
        SD.cluster(rounds=10, clust_range=[2, K], num_cores = -2, embeddings=embs)
        spk_labels = SD.speaker_labels_
    except ValueError:
        spk_labels = []
        failed.append(fail)
        continue
    base = os.path.basename(fail)
    long_name = video_mapping[base[:3]]
    j = results[long_name].index((base, []))
    results[long_name][j] = (base, spk_labels, K)
# Out:
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_008.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_018.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_023.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_027.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_045.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_064.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_085.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_092.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/175_099.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_010.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_019.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_036.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_039.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_049.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_060.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_081.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/176_085.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_017.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_028.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_041.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_045.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_048.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_049.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/177_073.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_011.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_015.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_017.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_022.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_025.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_027.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_034.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_037.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_038.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_040.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/178_046.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/179_015.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/179_023.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/179_032.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/179_062.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/180_009.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/180_011.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/180_014.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_001.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_014.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_019.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_024.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_036.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_052.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_062.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_066.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/181_075.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_020.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_034.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_035.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_037.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_038.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_041.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_051.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/182_056.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_006.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_016.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_022.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_025.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_054.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_060.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_063.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/183_080.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_014.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_020.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_046.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_053.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_064.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_068.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/184_069.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_002.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_009.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_021.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_024.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_026.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_034.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_041.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_045.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_046.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_050.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_061.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_065.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.5/185_066.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_011.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_017.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_020.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_023.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_032.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_034.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_036.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_039.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_043.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_046.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_051.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_057.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_058.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_069.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_071.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_072.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/175_079.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_003.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_013.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_014.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_015.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_020.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_022.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_024.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_032.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_036.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_039.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_043.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/176_050.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/177_011.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/177_019.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/177_025.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/177_026.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/177_028.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/178_005.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/178_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/179_017.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/179_020.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/179_028.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/179_029.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/179_032.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/180_001.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/180_005.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_008.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_019.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_023.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_024.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_030.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/181_052.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_009.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_010.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_014.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_019.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_033.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_035.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_036.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_039.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_042.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/182_050.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_006.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_009.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_024.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_026.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_032.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/183_045.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/184_004.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/184_007.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/184_013.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/184_038.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/184_040.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/184_055.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/185_009.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/185_010.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/185_013.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/185_026.wav now.
# Diarizing file ./data/segments_add1_keep1_cut0.7/185_030.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_015.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_024.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_045.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_051.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_063.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_074.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/175_077.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/176_017.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/176_032.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/176_041.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/176_054.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/176_067.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_002.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_014.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_028.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_030.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_034.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_046.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_050.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_051.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/177_057.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/178_012.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/178_021.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/178_031.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/179_012.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/179_034.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/180_007.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/180_012.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/180_013.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/181_010.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/181_017.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/181_028.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/181_055.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/182_008.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/182_011.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/182_031.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/182_047.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/182_060.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/183_012.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/183_026.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/183_028.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/183_042.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/183_058.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_006.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_020.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_027.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_030.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_045.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_046.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/184_064.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/185_007.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.5/185_053.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/175_002.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/175_031.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/175_043.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/176_019.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/177_002.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/177_006.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/177_015.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/178_017.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/179_005.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/179_021.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/181_003.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/181_010.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/181_016.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/181_026.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/181_039.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/182_004.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/182_022.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/182_032.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/182_038.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/183_001.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/183_006.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/183_008.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/183_010.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/183_018.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/183_020.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/184_006.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/184_007.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/184_013.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/184_030.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/184_042.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/185_002.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/185_004.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/185_008.wav now.
# Diarizing file ./data/segments_add1_keep2_cut0.7/185_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_001.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_003.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_021.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_022.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_023.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_030.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_039.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_059.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_061.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_062.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_080.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_087.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_088.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_095.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_103.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_108.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_110.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_112.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_117.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_122.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_123.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/175_126.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_005.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_006.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_008.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_011.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_017.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_028.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_035.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_053.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_054.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_055.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_058.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_064.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_069.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_070.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_074.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_084.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_087.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_096.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_102.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_114.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_117.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_119.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_123.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_124.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_125.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/176_127.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_003.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_013.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_019.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_022.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_023.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_030.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_055.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_056.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_057.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_064.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_065.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_073.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_078.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_081.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_086.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_088.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_094.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_108.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_115.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/177_116.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_027.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_036.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_037.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_051.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_057.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_075.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_077.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_082.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/178_085.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_002.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_004.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_015.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_019.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_032.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_048.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_057.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_071.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_077.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_079.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_086.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_091.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_094.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_095.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_097.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/179_098.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/180_005.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/180_007.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/180_016.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/180_017.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/180_022.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/180_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_004.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_008.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_015.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_022.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_023.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_030.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_069.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_079.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_080.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_087.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/181_091.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_027.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_032.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_043.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_045.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_050.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_055.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_070.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_074.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_075.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_079.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_092.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/182_099.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_006.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_010.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_013.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_023.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_035.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_036.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_047.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_064.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_071.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_072.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_077.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_080.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_082.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_084.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_100.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_104.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_105.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_106.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/183_107.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_002.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_008.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_010.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_017.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_023.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_033.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_040.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_050.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_056.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_058.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_065.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_066.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_072.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_079.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_080.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_082.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_086.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_087.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/184_088.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_007.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_012.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_016.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_023.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_030.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_045.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_052.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_054.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_055.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_064.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_066.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_069.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_073.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_085.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_096.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_097.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.5/185_098.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_003.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_004.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_011.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_012.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_015.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_017.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_018.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_019.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_021.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_026.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_031.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_034.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_035.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_037.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_040.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_042.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_043.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_046.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_049.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_051.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_053.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_055.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_057.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_062.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_064.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_065.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_066.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_067.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_070.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_071.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_080.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_084.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_085.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_088.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_099.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_100.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_104.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_106.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_108.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_110.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_112.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_114.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_115.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_117.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_123.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_127.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_136.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_143.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_145.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/175_147.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_005.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_006.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_007.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_010.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_011.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_013.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_015.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_019.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_021.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_026.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_034.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_035.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_036.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_039.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_046.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_048.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_050.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_051.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_053.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_055.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_062.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_064.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_067.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_072.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_077.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_081.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_082.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_086.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_088.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_092.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_094.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_095.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_096.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_100.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_102.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_103.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_106.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_108.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_113.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_114.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/176_121.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_001.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_006.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_007.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_012.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_028.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_032.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_037.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_039.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_040.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_041.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_042.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_043.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_048.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_049.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_059.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_060.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_069.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_071.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_073.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_076.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_078.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/177_082.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_001.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_004.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_006.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_013.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_024.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_030.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_037.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_040.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_046.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_048.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_049.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_050.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/178_053.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_004.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_007.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_008.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_011.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_015.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_016.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_020.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_026.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_027.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_029.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_031.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_033.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_036.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_045.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_048.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_049.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_051.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_054.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_057.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_062.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_072.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_073.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/179_074.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/180_010.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/180_011.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/180_012.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/180_017.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_007.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_008.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_011.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_012.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_014.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_019.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_020.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_021.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_033.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_039.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_040.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_043.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_048.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_058.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_063.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_066.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_071.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_078.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_081.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_085.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_087.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_088.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_092.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_098.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_099.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_102.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/181_106.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_001.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_003.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_004.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_006.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_009.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_010.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_013.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_015.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_020.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_025.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_026.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_029.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_033.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_036.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_037.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_038.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_044.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_047.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_050.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_065.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_068.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_073.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_075.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_083.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_086.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_091.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_098.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_101.wav now.
# Diarizing file ./data/segments_add1_keepall_cut0.7/182_109.wav now.
# ...
# Diarizing file ./data/segments_add2_keep2_cut0.5/175_023.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/175_027.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/176_002.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/176_003.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/176_030.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/177_037.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/178_020.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/178_025.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/179_005.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/181_020.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/182_011.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/183_001.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/183_010.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/183_021.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/183_031.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/184_002.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/184_020.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/185_024.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/185_035.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.5/185_039.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_003.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_008.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_014.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_038.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_042.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_045.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/175_050.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/176_002.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/176_005.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/176_008.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/176_015.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/176_039.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/177_018.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/177_027.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/178_005.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/178_020.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/179_002.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/179_016.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/181_005.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/181_006.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/181_011.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/181_020.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/181_025.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/181_027.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_002.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_015.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_022.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_026.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_028.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_029.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/182_041.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/183_003.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/183_028.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/184_012.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/185_002.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/185_003.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/185_008.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/185_020.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/185_022.wav now.
# Diarizing file ./data/segments_add2_keep2_cut0.7/185_028.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/175_009.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/175_034.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/175_035.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/176_003.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/176_023.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/176_024.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/176_028.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/176_047.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/176_050.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/177_018.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/177_026.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/178_008.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/178_011.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/178_025.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/178_029.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/178_030.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/179_017.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/179_028.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/179_036.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/181_002.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/182_021.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/183_031.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/183_033.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/183_034.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/183_035.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/184_011.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/184_020.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/184_021.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/185_003.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/185_010.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/185_019.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/185_027.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.5/185_047.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_003.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_017.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_023.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_027.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_030.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_033.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_037.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_047.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_061.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_068.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_072.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_074.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_079.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_092.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/175_094.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_004.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_006.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_008.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_024.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_029.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_030.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_033.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_035.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_040.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_050.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_057.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_058.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_061.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_064.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_066.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_067.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_075.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_076.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_077.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_080.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/176_081.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_010.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_018.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_031.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_039.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_047.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_048.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_052.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_063.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/177_065.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_004.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_008.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_014.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_015.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_021.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_027.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_028.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_032.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/178_041.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_002.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_006.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_007.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_014.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_024.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_028.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_031.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_033.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_034.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_035.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_038.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_053.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_057.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/179_058.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/180_009.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/180_010.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_005.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_008.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_009.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_012.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_020.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_037.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_038.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_046.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_047.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_050.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_065.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/181_078.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_014.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_020.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_039.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_044.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_045.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_054.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_058.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_061.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/182_067.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_001.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_025.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_028.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_040.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_043.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_062.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_076.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_077.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/183_080.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_001.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_003.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_005.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_007.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_010.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_012.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_017.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_018.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_020.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_024.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_026.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_029.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_033.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_038.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_039.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_047.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_053.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_054.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_055.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_056.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_061.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_063.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_071.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_075.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_076.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_078.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_085.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_088.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_091.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_093.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_097.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_101.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_102.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_106.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_107.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/184_114.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_001.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_003.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_005.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_012.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_021.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_027.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_031.wav now.
# Diarizing file ./data/segments_add2_keepall_cut0.7/185_043.wav now.
